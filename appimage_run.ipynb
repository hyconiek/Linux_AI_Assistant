# %%
# Komórka 1: Klonowanie repozytorium i przejście do katalogu projektu
# -*- coding: utf-8 -*-
"""
appimage_run.ipynb

Automatically generated by Colab.
"""
# Zastąp swoim URL repozytorium
GIT_REPO_URL = "https://github.com/hyconiek/linux_ai_terminal_assistant.git"
PROJECT_DIR_NAME = "linux_ai_terminal_assistant"

print(f"Klonowanie repozytorium: {GIT_REPO_URL}")
# !git clone {GIT_REPO_URL}
# %cd {PROJECT_DIR_NAME}
# !git checkout main # Odkomentuj, jeśli chcesz konkretną gałąź/tag
# Out:
# Klonowanie repozytorium: https://github.com/hyconiek/linux_ai_terminal_assistant.git
# Cloning into 'linux_ai_terminal_assistant'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 151 (delta 57), reused 124 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (151/151), 40.28 MiB | 33.81 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# /content/linux_ai_terminal_assistant

# %%
# Komórka 2: Instalacja zależności systemowych (zoptymalizowana lista)
print("Aktualizowanie listy pakietów...")
# !sudo apt-get update -qq

print("Instalowanie podstawowych zależności systemowych i deweloperskich Qt...")
# !sudo apt-get install -y \
    python3-pip python3-venv python3.11-venv \
    qtbase5-dev qttools5-dev qttools5-dev-tools \
    libqt5svg5 libqt5svg5-dev \
    libxkbcommon-x11-0 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-randr0 \
    libxcb-render-util0 libxcb-shape0 libxcb-xfixes0 libxcb-xinerama0 libxcb-xkb1 \
    libfontconfig1 libfreetype6 libgl1-mesa-glx libglib2.0-0 libice6 libjpeg-turbo8 \
    libpng16-16 libsm6 libwayland-client0 libwayland-cursor0 libwayland-egl1 \
    libx11-6 libx11-xcb1 libxau6 libxcb1 libxdmcp6 libxext6 libxi6 libxrender1 \
    patchelf desktop-file-utils libgdk-pixbuf2.0-0 fuse \
    wget build-essential libdbus-1-3 libxcb-util1 chrpath

print("Instalacja zależności systemowych zakończona.")
print("Pominięto pakiety Qt związane z multimediami, WebEngine, 3D, PDF, itp.")
# Out:
# Aktualizowanie listy pakietów...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Instalowanie podstawowych zależności systemowych i deweloperskich Qt...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# desktop-file-utils is already the newest version (0.26-1ubuntu3).
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libice6 is already the newest version (2:1.0.10-1build2).
# libjpeg-turbo8 is already the newest version (2.1.2-0ubuntu1).
# libpng16-16 is already the newest version (1.6.37-3build5).
# libsm6 is already the newest version (2:1.2.3-1build2).
# libxau6 is already the newest version (1:1.0.9-1build5).
# libxcb-icccm4 is already the newest version (0.4.1-1.1build2).
# libxcb-image0 is already the newest version (0.4.0-2).
# libxcb-keysyms1 is already the newest version (0.4.0-1build3).
# libxcb-randr0 is already the newest version (1.14-3ubuntu3).
# libxcb-render-util0 is already the newest version (0.3.9-1build3).
# libxcb-shape0 is already the newest version (1.14-3ubuntu3).
# libxcb-util1 is already the newest version (0.4.0-1build2).
# libxcb-xfixes0 is already the newest version (1.14-3ubuntu3).
# libxcb-xinerama0 is already the newest version (1.14-3ubuntu3).
# libxcb-xkb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxdmcp6 is already the newest version (1:1.1.3-0ubuntu5).
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxi6 is already the newest version (2:1.8-1build1).
# libxkbcommon-x11-0 is already the newest version (1.4.0-1).
# libxrender1 is already the newest version (1:0.9.10-1build4).
# chrpath is already the newest version (0.16-2).
# fuse is already the newest version (2.9.9-5ubuntu3).
# libgdk-pixbuf2.0-0 is already the newest version (2.40.2-2build4).
# libqt5svg5 is already the newest version (5.15.3-1).
# libqt5svg5-dev is already the newest version (5.15.3-1).
# patchelf is already the newest version (0.14.3-1).
# qttools5-dev is already the newest version (5.15.3-1).
# qttools5-dev-tools is already the newest version (5.15.3-1).
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.3).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.4).
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-cursor0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-egl1 is already the newest version (1.20.0-1ubuntu0.1).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-xcb1 is already the newest version (2:1.7.5-1ubuntu0.3).
# wget is already the newest version (1.21.2-2ubuntu1.1).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# python3-pip is already the newest version (22.0.2+dfsg-1ubuntu0.5).
# python3-venv is already the newest version (3.10.6-1~22.04.1).
# qtbase5-dev is already the newest version (5.15.3+dfsg-2ubuntu0.2).
# python3.11-venv is already the newest version (3.11.12-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 91 not upgraded.
# Instalacja zależności systemowych zakończona.
# Pominięto pakiety Qt związane z multimediami, WebEngine, 3D, PDF, itp.

# %%
# Komórka 3: Pobieranie narzędzi AppImage (linuxdeployqt i appimagetool)
import os
# %cd /content

print("Pobieranie linuxdeployqt...")
# !wget -q "https://github.com/probonopd/linuxdeployqt/releases/download/continuous/linuxdeployqt-continuous-x86_64.AppImage" -O linuxdeployqt
# !chmod +x linuxdeployqt
if not os.path.exists("/content/linuxdeployqt"):
    print("BŁĄD: Nie udało się pobrać linuxdeployqt!")
else:
    print("linuxdeployqt pobrane.")
    # !./linuxdeployqt --version

print("\nPobieranie appimagetool...")
# !wget -q "https://github.com/AppImage/AppImageKit/releases/download/continuous/appimagetool-x86_64.AppImage" -O appimagetool
# !chmod +x appimagetool
if not os.path.exists("/content/appimagetool"):
    print("BŁĄD: Nie udało się pobrać appimagetool!")
else:
    print("appimagetool pobrane.")
    # !./appimagetool --version

# Dodanie /content do PATH
current_path = os.environ.get('PATH', '')
content_path = "/content"
if content_path not in current_path.split(os.pathsep):
    os.environ['PATH'] = f"{content_path}{os.pathsep}{current_path}"
    print(f"\nDodano {content_path} do PATH.")
# Out:
# /content/linux_ai_terminal_assistant
# Pobieranie linuxdeployqt...
# linuxdeployqt pobrane.
# linuxdeployqt  (commit 37df8a3), build 91 built on 2025-05-04 15:05:54 UTC
#
# Pobieranie appimagetool...
# appimagetool pobrane.
# appimagetool, continuous build (commit 5735cc5), build <local dev build> built on 2023-03-08 22:52:04 UTC

# %%
# Komórka 4: Definicja globalnych zmiennych konfiguracyjnych
import os

COLAB_CONTENT_DIR = "/content"
PROJECT_DIR_NAME = "linux_ai_terminal_assistant" # Musi pasować do nazwy z komórki 1
PROJECT_ROOT_IN_COLAB = os.path.join(COLAB_CONTENT_DIR, PROJECT_DIR_NAME)

ICON_FILENAME = "app_icon.png" # Upewnij się, że ten plik istnieje w repozytorium
ICON_SOURCE_PATH = os.path.join(PROJECT_ROOT_IN_COLAB, ICON_FILENAME)

APPDIR_NAME = "LinuxAIAssistant.AppDir"
APPDIR_FULL_PATH = os.path.join(COLAB_CONTENT_DIR, APPDIR_NAME)

PYINSTALLER_APP_NAME = "Linux AI Assistant" # Nazwa aplikacji używana przez PyInstaller
PYINSTALLER_DIST_DIR_FULL_PATH = os.path.join(PROJECT_ROOT_IN_COLAB, "dist", PYINSTALLER_APP_NAME)
APP_EXECUTABLE_NAME_FROM_PYINSTALLER = PYINSTALLER_APP_NAME # Plik wykonywalny z PyInstallera

APP_EXECUTABLE_NAME_IN_APPDIR_ROOT = "LinuxAIAssistant" # Docelowa nazwa pliku wykonywalnego w AppDir
ICON_DESKTOP_ENTRY_NAME = "linux-ai-assistant"
ICON_APPDIR_TOPLEVEL_FILENAME = f"{ICON_DESKTOP_ENTRY_NAME}.png"

VENV_PATH = os.path.join(PROJECT_ROOT_IN_COLAB, "venv")
PYTHON_VENV_EXEC = os.path.join(VENV_PATH, "bin", "python")
PYINSTALLER_EXEC = os.path.join(VENV_PATH, "bin", "pyinstaller")


print(f"PROJECT_ROOT_IN_COLAB: {PROJECT_ROOT_IN_COLAB}")
print(f"APPDIR_FULL_PATH: {APPDIR_FULL_PATH}")
print(f"PYINSTALLER_DIST_DIR_FULL_PATH: {PYINSTALLER_DIST_DIR_FULL_PATH}")
# Out:
# PROJECT_ROOT_IN_COLAB: /content/linux_ai_terminal_assistant
# APPDIR_FULL_PATH: /content/LinuxAIAssistant.AppDir
# PYINSTALLER_DIST_DIR_FULL_PATH: /content/linux_ai_terminal_assistant/dist/Linux AI Assistant

# %%
# Komórka 5: Konfiguracja środowiska wirtualnego Python i instalacja zależności projektu
import os
import sys # Potrzebne do uzyskania systemowego interpretera Pythona

# Upewnij się, że jesteśmy w katalogu projektu, gdzie ma powstać venv
if os.getcwd() != PROJECT_ROOT_IN_COLAB:
    print(f"Zmieniam katalog na: {PROJECT_ROOT_IN_COLAB}")
    # %cd {PROJECT_ROOT_IN_COLAB}
else:
    print(f"Już jestem w katalogu projektu: {PROJECT_ROOT_IN_COLAB}")

# Użyj systemowego interpretera Pythona do stworzenia venv
# Zakładamy, że python3 wskazuje na odpowiednią wersję (np. 3.11, jak zainstalowano w komórce 2)
SYSTEM_PYTHON_EXEC = sys.executable # To da pełną ścieżkę do bieżącego interpretera (w Colab to zwykle systemowy)
# Alternatywnie, jeśli chcesz być pewien wersji 3.11:
# SYSTEM_PYTHON_EXEC = "/usr/bin/python3.11" # Jeśli wiesz, że taka ścieżka istnieje po apt install

print(f"Używam systemowego interpretera Pythona: {SYSTEM_PYTHON_EXEC}")
print(f"Tworzenie środowiska wirtualnego venv w: {VENV_PATH}")
# !{SYSTEM_PYTHON_EXEC} -m venv {VENV_PATH} # Usuń istniejący venv, jeśli istnieje
if os.path.exists(VENV_PATH):
    print(f"Usuwanie istniejącego środowiska venv: {VENV_PATH}")
    # !rm -rf {VENV_PATH}
# !{SYSTEM_PYTHON_EXEC} -m venv {VENV_PATH}

print("\nInstalowanie/aktualizowanie pip, setuptools, wheel w venv...")
# !{PYTHON_VENV_EXEC} -m pip install --upgrade pip setuptools wheel

print("\nInstalowanie zależności z requirements.txt...")
# Upewnij się, że plik requirements.txt istnieje w PROJECT_ROOT_IN_COLAB
requirements_file_path = os.path.join(PROJECT_ROOT_IN_COLAB, "requirements.txt")
if os.path.exists(requirements_file_path):
    # !{PYTHON_VENV_EXEC} -m pip install -r {requirements_file_path}
else:
    print(f"OSTRZEŻENIE: Plik requirements.txt nie został znaleziony w '{requirements_file_path}'. Zależności nie zostały zainstalowane.")

print("\nInstalowanie PyInstaller w venv...")
# !{PYTHON_VENV_EXEC} -m pip install pyinstaller

print("\nZakończono konfigurację środowiska Python.")
# Out:
# Zmieniam katalog na: /content/linux_ai_terminal_assistant
# /content/linux_ai_terminal_assistant
# Używam systemowego interpretera Pythona: /usr/bin/python3
# Tworzenie środowiska wirtualnego venv w: /content/linux_ai_terminal_assistant/venv
# Usuwanie istniejącego środowiska venv: /content/linux_ai_terminal_assistant/venv
#
# Instalowanie/aktualizowanie pip, setuptools, wheel w venv...
# Requirement already satisfied: pip in ./venv/lib/python3.11/site-packages (24.0)
# Collecting pip
#   Using cached pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in ./venv/lib/python3.11/site-packages (65.5.0)
# Collecting setuptools
#   Using cached setuptools-80.8.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wheel
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Using cached pip-25.1.1-py3-none-any.whl (1.8 MB)
# Using cached setuptools-80.8.0-py3-none-any.whl (1.2 MB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-25.1.1 setuptools-80.8.0 wheel-0.45.1
#
# Instalowanie zależności z requirements.txt...
# Collecting colorama>=0.4.4 (from -r /content/linux_ai_terminal_assistant/requirements.txt (line 1))
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting requests>=2.25.1 (from -r /content/linux_ai_terminal_assistant/requirements.txt (line 2))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting shell-gpt>=0.9.0 (from -r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached shell_gpt-1.4.5-py3-none-any.whl.metadata (28 kB)
# Collecting configparser>=5.0.0 (from -r /content/linux_ai_terminal_assistant/requirements.txt (line 4))
#   Using cached configparser-7.2.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting google-generativeai>=0.5.0 (from -r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached google_generativeai-0.8.5-py3-none-any.whl.metadata (3.9 kB)
# Collecting PyQt5>=5.15.0 (from -r /content/linux_ai_terminal_assistant/requirements.txt (line 6))
#   Using cached PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.25.1->-r /content/linux_ai_terminal_assistant/requirements.txt (line 2))
#   Using cached charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.25.1->-r /content/linux_ai_terminal_assistant/requirements.txt (line 2))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.25.1->-r /content/linux_ai_terminal_assistant/requirements.txt (line 2))
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.25.1->-r /content/linux_ai_terminal_assistant/requirements.txt (line 2))
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Collecting click<9.0.0,>=7.1.1 (from shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting distro<2.0.0,>=1.8.0 (from shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting instructor<2.0.0,>=1.0.0 (from shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached instructor-1.8.3-py3-none-any.whl.metadata (24 kB)
# Collecting openai<2.0.0,>=1.34.0 (from shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached openai-1.82.0-py3-none-any.whl.metadata (25 kB)
# Collecting rich<14.0.0,>=13.1.0 (from shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting typer<1.0.0,>=0.7.0 (from shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached typer-0.15.4-py3-none-any.whl.metadata (15 kB)
# Collecting aiohttp<4.0.0,>=3.9.1 (from instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached aiohttp-3.11.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting docstring-parser<1.0,>=0.16 (from instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting jinja2<4.0.0,>=3.1.4 (from instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting jiter<0.9,>=0.6.1 (from instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached jiter-0.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting pydantic-core<3.0.0,>=2.18.0 (from instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached pydantic_core-2.34.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting pydantic<3.0.0,>=2.8.0 (from instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached pydantic-2.11.5-py3-none-any.whl.metadata (67 kB)
# Collecting tenacity<10.0.0,>=9.0.0 (from instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.9.1->instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.9.1->instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.9.1->instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.9.1->instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached frozenlist-1.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.9.1->instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached multidict-6.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.9.1->instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached propcache-0.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.9.1->instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached yarl-1.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (72 kB)
# Collecting MarkupSafe>=2.0 (from jinja2<4.0.0,>=3.1.4->instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting anyio<5,>=3.5.0 (from openai<2.0.0,>=1.34.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.34.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting sniffio (from openai<2.0.0,>=1.34.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<2.0.0,>=1.34.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting typing-extensions<5,>=4.11 (from openai<2.0.0,>=1.34.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.34.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.34.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.8.0->instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core<3.0.0,>=2.18.0 (from instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.8.0->instructor<2.0.0,>=1.0.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14.0.0,>=13.1.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich<14.0.0,>=13.1.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting click<9.0.0,>=7.1.1 (from shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.7.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting google-ai-generativelanguage==0.6.15 (from google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl.metadata (5.7 kB)
# Collecting google-api-core (from google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-python-client (from google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached google_api_python_client-2.170.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=2.15.0 (from google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached google_auth-2.40.2-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting protobuf (from google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached protobuf-6.31.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting google-api-core (from google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached google_api_core-2.25.0rc1-py3-none-any.whl.metadata (3.0 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.6.15->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf (from google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached grpcio-1.71.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached grpcio_status-1.71.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.15.0->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=2.15.0->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting PyQt5-sip<13,>=12.15 (from PyQt5>=5.15.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 6))
#   Using cached PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (472 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from PyQt5>=5.15.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 6))
#   Using cached PyQt5_Qt5-5.15.16-1-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.1.0->shell-gpt>=0.9.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 3))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai>=0.5.0->-r /content/linux_ai_terminal_assistant/requirements.txt (line 5))
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached shell_gpt-1.4.5-py3-none-any.whl (30 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached instructor-1.8.3-py3-none-any.whl (94 kB)
# Using cached aiohttp-3.11.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# Using cached docstring_parser-0.16-py3-none-any.whl (36 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached jiter-0.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
# Using cached multidict-6.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (223 kB)
# Using cached openai-1.82.0-py3-none-any.whl (720 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pydantic-2.11.5-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached pygments-2.19.1-py3-none-any.whl (1.2 MB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typer-0.15.4-py3-none-any.whl (45 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Using cached yarl-1.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (358 kB)
# Using cached configparser-7.2.0-py3-none-any.whl (17 kB)
# Using cached google_generativeai-0.8.5-py3-none-any.whl (155 kB)
# Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
# Using cached google_api_core-2.25.0rc1-py3-none-any.whl (160 kB)
# Using cached google_auth-2.40.2-py2.py3-none-any.whl (216 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Using cached grpcio-1.71.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# Using cached grpcio_status-1.71.0-py3-none-any.whl (14 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
# Using cached PyQt5_Qt5-5.15.16-1-py3-none-manylinux2014_x86_64.whl (61.1 MB)
# Using cached PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl (276 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Using cached frozenlist-1.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Using cached propcache-0.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (232 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached google_api_python_client-2.170.0-py3-none-any.whl (13.5 MB)
# Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Installing collected packages: PyQt5-Qt5, urllib3, uritemplate, typing-extensions, tqdm, tenacity, sniffio, shellingham, PyQt5-sip, pyparsing, pygments, pyasn1, protobuf, propcache, multidict, mdurl, MarkupSafe, jiter, idna, h11, grpcio, frozenlist, docstring-parser, distro, configparser, colorama, click, charset-normalizer, certifi, cachetools, attrs, annotated-types, aiohappyeyeballs, yarl, typing-inspection, rsa, requests, PyQt5, pydantic-core, pyasn1-modules, proto-plus, markdown-it-py, jinja2, httplib2, httpcore, googleapis-common-protos, anyio, aiosignal, rich, pydantic, httpx, grpcio-status, google-auth, aiohttp, typer, openai, google-auth-httplib2, google-api-core, instructor, google-api-python-client, shell-gpt, google-ai-generativelanguage, google-generativeai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63/63 [google-generativeai]
# Successfully installed MarkupSafe-3.0.2 PyQt5-5.15.11 PyQt5-Qt5-5.15.16 PyQt5-sip-12.17.0 aiohappyeyeballs-2.6.1 aiohttp-3.11.18 aiosignal-1.3.2 annotated-types-0.7.0 anyio-4.9.0 attrs-25.3.0 cachetools-5.5.2 certifi-2025.4.26 charset-normalizer-3.4.2 click-8.1.8 colorama-0.4.6 configparser-7.2.0 distro-1.9.0 docstring-parser-0.16 frozenlist-1.6.0 google-ai-generativelanguage-0.6.15 google-api-core-2.25.0rc1 google-api-python-client-2.170.0 google-auth-2.40.2 google-auth-httplib2-0.2.0 google-generativeai-0.8.5 googleapis-common-protos-1.70.0 grpcio-1.71.0 grpcio-status-1.71.0 h11-0.16.0 httpcore-1.0.9 httplib2-0.22.0 httpx-0.28.1 idna-3.10 instructor-1.8.3 jinja2-3.1.6 jiter-0.8.2 markdown-it-py-3.0.0 mdurl-0.1.2 multidict-6.4.4 openai-1.82.0 propcache-0.3.1 proto-plus-1.26.1 protobuf-5.29.4 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.11.5 pydantic-core-2.33.2 pygments-2.19.1 pyparsing-3.2.3 requests-2.32.3 rich-13.9.4 rsa-4.9.1 shell-gpt-1.4.5 shellingham-1.5.4 sniffio-1.3.1 tenacity-9.1.2 tqdm-4.67.1 typer-0.15.4 typing-extensions-4.13.2 typing-inspection-0.4.1 uritemplate-4.1.1 urllib3-2.4.0 yarl-1.20.0
#
# Instalowanie PyInstaller w venv...
# Collecting pyinstaller
#   Using cached pyinstaller-6.13.0-py3-none-manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: setuptools>=42.0.0 in ./venv/lib/python3.11/site-packages (from pyinstaller) (80.8.0)
# Collecting altgraph (from pyinstaller)
#   Using cached altgraph-0.17.4-py2.py3-none-any.whl.metadata (7.3 kB)
# Collecting pyinstaller-hooks-contrib>=2025.2 (from pyinstaller)
#   Using cached pyinstaller_hooks_contrib-2025.4-py3-none-any.whl.metadata (16 kB)
# Collecting packaging>=22.0 (from pyinstaller)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached pyinstaller-6.13.0-py3-none-manylinux2014_x86_64.whl (721 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pyinstaller_hooks_contrib-2025.4-py3-none-any.whl (434 kB)
# Using cached altgraph-0.17.4-py2.py3-none-any.whl (21 kB)
# Installing collected packages: altgraph, packaging, pyinstaller-hooks-contrib, pyinstaller
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pyinstaller]
# Successfully installed altgraph-0.17.4 packaging-25.0 pyinstaller-6.13.0 pyinstaller-hooks-contrib-2025.4
#
# Zakończono konfigurację środowiska Python.

# %%
# Komórka 6: Budowanie aplikacji za pomocą PyInstaller
import os
import subprocess
# Zakładamy, że zmienne globalne jak PROJECT_ROOT_IN_COLAB, VENV_PATH, PYTHON_VENV_EXEC,
# PYINSTALLER_EXEC, PYINSTALLER_APP_NAME, ICON_FILENAME są zdefiniowane w Komórce 4.
# Zmienna pyqt5_dir_path jest ustalana na początku tej komórki.

# Upewnij się, że jesteśmy w katalogu projektu, gdzie jest główny skrypt GUI
if os.getcwd() != PROJECT_ROOT_IN_COLAB:
    print(f"Zmieniam katalog na: {PROJECT_ROOT_IN_COLAB} (był: {os.getcwd()})")
    os.chdir(PROJECT_ROOT_IN_COLAB)
else:
    print(f"Już jestem w katalogu projektu: {PROJECT_ROOT_IN_COLAB}")

# Próba uzyskania ścieżki do katalogu PyQt5 w venv (powtórzenie z poprzedniej wersji dla kompletności)
pyqt5_dir_path = None
print("\nPróba uzyskania ścieżki do katalogu PyQt5 z venv...")
get_pyqt5_path_script = "import PyQt5, os; print(os.path.dirname(PyQt5.__file__))"
try:
    result = subprocess.run([PYTHON_VENV_EXEC, "-c", get_pyqt5_path_script],
                            capture_output=True, text=True, check=True)
    pyqt5_dir_path = result.stdout.strip()
    if os.path.isdir(pyqt5_dir_path):
        print(f"Znaleziona ścieżka do katalogu PyQt5 w venv: {pyqt5_dir_path}")
    else:
        print(f"OSTRZEŻENIE: Uzyskana ścieżka PyQt5 ('{pyqt5_dir_path}') nie jest poprawnym katalogiem.")
        pyqt5_dir_path = None
except subprocess.CalledProcessError as e:
    print(f"BŁĄD podczas próby uzyskania ścieżki PyQt5 z venv: {e.stderr.strip() if e.stderr else 'Brak STDERR'}")
except FileNotFoundError:
    print(f"BŁĄD: Nie znaleziono interpretera Pythona w venv: {PYTHON_VENV_EXEC}")

# --- Definicja ścieżek dla Lorem ipsum.txt ---
# Najpierw spróbuj ścieżki, gdzie jest vendored przez setuptools
lorem_ipsum_source_path_setuptools = os.path.join(VENV_PATH, "lib/python3.11/site-packages/setuptools/_vendor/jaraco/text/Lorem ipsum.txt")
# Potem spróbuj ścieżki, jakby jaraco.text było oddzielnym pakietem
lorem_ipsum_source_path_jaraco = os.path.join(VENV_PATH, "lib/python3.11/site-packages/jaraco/text/Lorem ipsum.txt")

lorem_ipsum_actual_source_path = None
lorem_ipsum_target_dir_in_internal = None

if os.path.exists(lorem_ipsum_source_path_setuptools):
    lorem_ipsum_actual_source_path = lorem_ipsum_source_path_setuptools
    lorem_ipsum_target_dir_in_internal = "setuptools/_vendor/jaraco/text"
    print(f"Znaleziono Lorem ipsum.txt w ścieżce setuptools: {lorem_ipsum_actual_source_path}")
elif os.path.exists(lorem_ipsum_source_path_jaraco):
    lorem_ipsum_actual_source_path = lorem_ipsum_source_path_jaraco
    lorem_ipsum_target_dir_in_internal = "jaraco/text"
    print(f"Znaleziono Lorem ipsum.txt w ścieżce jaraco.text: {lorem_ipsum_actual_source_path}")
else:
    print(f"OSTRZEŻENIE: Nie znaleziono pliku źródłowego Lorem ipsum.txt ani w '{lorem_ipsum_source_path_setuptools}', ani w '{lorem_ipsum_source_path_jaraco}'. Nie zostanie dodany.")

print("\nRozpoczynanie budowania z PyInstaller...")
pyinstaller_command_list = [
    PYINSTALLER_EXEC,
    "--name", PYINSTALLER_APP_NAME,
    "--noconfirm",
    "--onedir",
    "--windowed",
    "--strip",
    # Dane podstawowe
    "--add-data", f"{ICON_FILENAME}:.",      # Ikona aplikacji
    "--add-data", "src:src",               # Twój kod źródłowy z katalogu src
]

# Dodaj cały katalog PyQt5, jeśli został znaleziony
if pyqt5_dir_path and os.path.isdir(pyqt5_dir_path):
    print(f"Dodaję cały katalog PyQt5 ('{pyqt5_dir_path}') przez --add-data jako 'PyQt5'.")
    pyinstaller_command_list.extend(["--add-data", f"{pyqt5_dir_path}:PyQt5"])
else:
    print("OSTRZEŻENIE: Nie znaleziono katalogu PyQt5 lub ścieżka jest niepoprawna. Katalog PyQt5 nie zostanie dodany przez --add-data.")

# Dodaj plik Lorem ipsum.txt, jeśli został znaleziony
if lorem_ipsum_actual_source_path and lorem_ipsum_target_dir_in_internal:
    print(f"Dodaję plik Lorem ipsum: {lorem_ipsum_actual_source_path} do katalogu docelowego: {lorem_ipsum_target_dir_in_internal}")
    # Poprawiona ścieżka docelowa, aby plik trafił do _internal/
pyinstaller_command_list.extend(["--add-data", f"{lorem_ipsum_actual_source_path}:_internal/{lorem_ipsum_target_dir_in_internal}"])

# Wykluczenia modułów
modules_to_exclude = [
    "PyQt5.QtWebSockets", "PyQt5.QtQml", "PyQt5.QtQuick", "PyQt5.QtMultimedia",
    "PyQt5.QtNetworkAuth", "PyQt5.QtBluetooth", "PyQt5.QtNfc", "PyQt5.QtSensors",
    "PyQt5.QtSerialPort", "PyQt5.QtPositioning", "PyQt5.QtLocation", "PyQt5.QtTextToSpeech",
    "PyQt5.QtWebEngineWidgets", "PyQt5.QtWebEngineCore", "PyQt5.QtWebView",
    "PyQt5.QtSql", "PyQt5.QtTest", "PyQt5.QtHelp", "PyQt5.QtDesigner",
    "PyQt5.Qt3DCore", "PyQt5.Qt3DRender", "PyQt5.Qt3DInput", "PyQt5.Qt3DLogic",
    "PyQt5.Qt3DAnimation", "PyQt5.Qt3DExtras", "PyQt5.QtQuick3D"
]
for mod in modules_to_exclude:
    pyinstaller_command_list.extend(["--exclude-module", mod])

# Hidden imports
hidden_imports_list = [
    "PyQt5.sip", "PyQt5.QtCore", "PyQt5.QtGui", "PyQt5.QtWidgets", "PyQt5.QtSvg",
    "PyQt5.QtPrintSupport", # Zostaw jeśli jest szansa na użycie drukowania/zapisu do PDF
    "google.generativeai", "google.ai.generativelanguage", "google.auth", "google.api_core",
    "google.protobuf", "google.type", "google.rpc",
    # "google.longrunning", # Zwykle wciągane przez api_core
    # "google.oauth2",      # Zwykle wciągane przez auth
    "proto", "grpc", "PIL", "pkg_resources", "argparse", "backend_cli"
]
for imp in hidden_imports_list:
    pyinstaller_command_list.extend(["--hidden-import", imp])

# Główny skrypt aplikacji
pyinstaller_command_list.append("linux_ai_assistant_gui.py")

print(f"\nFinalna komenda PyInstaller:\n{' '.join(pyinstaller_command_list)}\n")

try:
    process_pyinstaller = subprocess.run(pyinstaller_command_list, cwd=PROJECT_ROOT_IN_COLAB, check=True, capture_output=True, text=True)
    print("--- PyInstaller STDOUT ---")
    print(process_pyinstaller.stdout)
    if process_pyinstaller.stderr:
        print("--- PyInstaller STDERR ---")
        print(process_pyinstaller.stderr)
    print("\nZakończono budowanie z PyInstaller. Sprawdź katalog 'dist'.")
except subprocess.CalledProcessError as e:
    print("BŁĄD KRYTYCZNY podczas działania PyInstallera!")
    print(f"Return code: {e.returncode}")
    print(f"--- PyInstaller STDOUT (on error) ---\n{e.stdout}")
    print(f"--- PyInstaller STDERR (on error) ---\n{e.stderr}")
    raise
except FileNotFoundError:
    print(f"BŁĄD KRYTYCZNY: Nie znaleziono wykonywalnego PyInstallera: {PYINSTALLER_EXEC}")
    raise

print("\nSprawdzanie zawartości katalogu PyInstallera (dist):")
# !find "{PYINSTALLER_DIST_DIR_FULL_PATH}" -maxdepth 2 -ls
print(f"\nW poszukiwaniu libpython w '{PYINSTALLER_DIST_DIR_FULL_PATH}':")
# !find "{PYINSTALLER_DIST_DIR_FULL_PATH}" -name "libpython*" -ls
print(f"\nW poszukiwaniu Lorem ipsum.txt w '{os.path.join(PYINSTALLER_DIST_DIR_FULL_PATH, '_internal')}':")
# !find "{os.path.join(PYINSTALLER_DIST_DIR_FULL_PATH, '_internal')}" -name "Lorem ipsum.txt" -ls
# Out:
# Już jestem w katalogu projektu: /content/linux_ai_terminal_assistant
#
# Próba uzyskania ścieżki do katalogu PyQt5 z venv...
# Znaleziona ścieżka do katalogu PyQt5 w venv: /content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5
# Znaleziono Lorem ipsum.txt w ścieżce setuptools: /content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/setuptools/_vendor/jaraco/text/Lorem ipsum.txt
#
# Rozpoczynanie budowania z PyInstaller...
# Dodaję cały katalog PyQt5 ('/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5') przez --add-data jako 'PyQt5'.
# Dodaję plik Lorem ipsum: /content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/setuptools/_vendor/jaraco/text/Lorem ipsum.txt do katalogu docelowego: setuptools/_vendor/jaraco/text
#
# Finalna komenda PyInstaller:
# /content/linux_ai_terminal_assistant/venv/bin/pyinstaller --name Linux AI Assistant --noconfirm --onedir --windowed --strip --add-data app_icon.png:. --add-data src:src --add-data /content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5:PyQt5 --add-data /content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/setuptools/_vendor/jaraco/text/Lorem ipsum.txt:_internal/setuptools/_vendor/jaraco/text --exclude-module PyQt5.QtWebSockets --exclude-module PyQt5.QtQml --exclude-module PyQt5.QtQuick --exclude-module PyQt5.QtMultimedia --exclude-module PyQt5.QtNetworkAuth --exclude-module PyQt5.QtBluetooth --exclude-module PyQt5.QtNfc --exclude-module PyQt5.QtSensors --exclude-module PyQt5.QtSerialPort --exclude-module PyQt5.QtPositioning --exclude-module PyQt5.QtLocation --exclude-module PyQt5.QtTextToSpeech --exclude-module PyQt5.QtWebEngineWidgets --exclude-module PyQt5.QtWebEngineCore --exclude-module PyQt5.QtWebView --exclude-module PyQt5.QtSql --exclude-module PyQt5.QtTest --exclude-module PyQt5.QtHelp --exclude-module PyQt5.QtDesigner --exclude-module PyQt5.Qt3DCore --exclude-module PyQt5.Qt3DRender --exclude-module PyQt5.Qt3DInput --exclude-module PyQt5.Qt3DLogic --exclude-module PyQt5.Qt3DAnimation --exclude-module PyQt5.Qt3DExtras --exclude-module PyQt5.QtQuick3D --hidden-import PyQt5.sip --hidden-import PyQt5.QtCore --hidden-import PyQt5.QtGui --hidden-import PyQt5.QtWidgets --hidden-import PyQt5.QtSvg --hidden-import PyQt5.QtPrintSupport --hidden-import google.generativeai --hidden-import google.ai.generativelanguage --hidden-import google.auth --hidden-import google.api_core --hidden-import google.protobuf --hidden-import google.type --hidden-import google.rpc --hidden-import proto --hidden-import grpc --hidden-import PIL --hidden-import pkg_resources --hidden-import argparse --hidden-import backend_cli linux_ai_assistant_gui.py
#
# --- PyInstaller STDOUT ---
#
# --- PyInstaller STDERR ---
# 105 INFO: PyInstaller: 6.13.0, contrib hooks: 2025.4
# 105 INFO: Python: 3.11.12
# 107 INFO: Platform: Linux-6.1.123+-x86_64-with-glibc2.35
# 107 INFO: Python environment: /content/linux_ai_terminal_assistant/venv
# 108 INFO: wrote /content/linux_ai_terminal_assistant/Linux AI Assistant.spec
# 110 INFO: Module search paths (PYTHONPATH):
# ['/env/python',
#  '/usr/lib/python311.zip',
#  '/usr/lib/python3.11',
#  '/usr/lib/python3.11/lib-dynload',
#  '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages',
#  '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/setuptools/_vendor',
#  '/content/linux_ai_terminal_assistant']
# 326 INFO: Appending 'datas' from .spec
# 377 INFO: checking Analysis
# 482 INFO: Building because excludes changed
# 482 INFO: Running Analysis Analysis-00.toc
# 482 INFO: Target bytecode optimization level: 0
# 482 INFO: Initializing module dependency graph...
# 483 INFO: Initializing module graph hook caches...
# 492 INFO: Analyzing modules for base_library.zip ...
# 1488 INFO: Processing standard module hook 'hook-heapq.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 1611 INFO: Processing standard module hook 'hook-encodings.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 3516 INFO: Processing standard module hook 'hook-pickle.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 5415 INFO: Caching module dependency graph...
# 5474 INFO: Looking for Python shared library...
# 5496 INFO: Using Python shared library: /lib/x86_64-linux-gnu/libpython3.11.so.1.0
# 5496 INFO: Analyzing /content/linux_ai_terminal_assistant/linux_ai_assistant_gui.py
# 6520 INFO: Processing standard module hook 'hook-PyQt5.QtWidgets.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 6657 INFO: Processing standard module hook 'hook-PyQt5.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 7560 INFO: Processing standard module hook 'hook-PyQt5.QtCore.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 8408 INFO: Processing standard module hook 'hook-PyQt5.QtGui.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 9312 INFO: Analyzing hidden import 'PyQt5.QtSvg'
# 9332 INFO: Processing standard module hook 'hook-PyQt5.QtSvg.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 9428 INFO: Analyzing hidden import 'PyQt5.QtPrintSupport'
# 9471 INFO: Processing standard module hook 'hook-PyQt5.QtPrintSupport.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 9586 INFO: Analyzing hidden import 'google.generativeai'
# 9641 INFO: Processing standard module hook 'hook-google.api_core.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 10893 INFO: Processing standard module hook 'hook-grpc.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 11201 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 11612 INFO: Processing standard module hook 'hook-xml.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 12830 INFO: Processing standard module hook 'hook-platform.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 12853 INFO: Processing standard module hook 'hook-urllib3.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 12983 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 12984 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 18994 INFO: Processing standard module hook 'hook-charset_normalizer.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 19146 INFO: Processing standard module hook 'hook-certifi.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 19885 INFO: Processing standard module hook 'hook-difflib.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 20126 INFO: Processing standard module hook 'hook-sysconfig.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 26861 INFO: Processing standard module hook 'hook-pydantic.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# /content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/pydantic/experimental/__init__.py:7: PydanticExperimentalWarning: This module is experimental, its contents are subject to change and deprecation.
#   warnings.warn(
# 27872 INFO: Processing standard module hook 'hook-pygments.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 29735 INFO: Processing standard module hook 'hook-zoneinfo.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 30898 INFO: Processing standard module hook 'hook-httplib2.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 31209 INFO: Processing standard module hook 'hook-jinja2.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 32041 INFO: Processing standard module hook 'hook-googleapiclient.model.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 32569 INFO: Processing pre-safe-import-module hook 'hook-importlib_resources.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 32596 INFO: Analyzing hidden import 'google.type'
# 32596 INFO: Analyzing hidden import 'pkg_resources'
# 32705 INFO: Processing standard module hook 'hook-pkg_resources.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 32934 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 32945 INFO: Processing standard module hook 'hook-packaging.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 33062 INFO: Processing pre-safe-import-module hook 'hook-jaraco.text.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 33062 INFO: Setuptools: 'jaraco.text' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco.text'!
# 33068 INFO: Processing standard module hook 'hook-setuptools.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 33081 INFO: Processing pre-safe-import-module hook 'hook-distutils.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 33081 INFO: Processing pre-find-module-path hook 'hook-distutils.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_find_module_path'
# 33298 INFO: Processing standard module hook 'hook-distutils.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 33328 INFO: Processing standard module hook 'hook-distutils.util.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 33450 INFO: Processing standard module hook 'hook-_osx_support.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 33567 INFO: Processing pre-safe-import-module hook 'hook-more_itertools.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 33568 INFO: Setuptools: 'more_itertools' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.more_itertools'!
# 33739 INFO: Processing pre-safe-import-module hook 'hook-jaraco.functools.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 33739 INFO: Setuptools: 'jaraco.functools' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco.functools'!
# 33750 INFO: Processing pre-safe-import-module hook 'hook-importlib_metadata.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 33750 INFO: Setuptools: 'importlib_metadata' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.importlib_metadata'!
# 33786 INFO: Processing standard module hook 'hook-setuptools._vendor.importlib_metadata.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 33790 INFO: Processing pre-safe-import-module hook 'hook-zipp.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 33790 INFO: Setuptools: 'zipp' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.zipp'!
# 34485 INFO: Processing pre-safe-import-module hook 'hook-tomli.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 34485 INFO: Setuptools: 'tomli' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.tomli'!
# 35599 INFO: Processing pre-safe-import-module hook 'hook-wheel.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 36015 INFO: Processing standard module hook 'hook-setuptools._vendor.jaraco.text.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 36017 INFO: Processing pre-safe-import-module hook 'hook-jaraco.context.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 36018 INFO: Setuptools: 'jaraco.context' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco.context'!
# 36032 INFO: Processing pre-safe-import-module hook 'hook-backports.tarfile.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 36033 INFO: Setuptools: 'backports.tarfile' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.backports.tarfile'!
# 36204 INFO: Processing standard module hook 'hook-backports.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 36206 INFO: Processing pre-safe-import-module hook 'hook-platformdirs.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 36207 INFO: Setuptools: 'platformdirs' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.platformdirs'!
# 36346 INFO: Processing module hooks (post-graph stage)...
# 36681 WARNING: Hidden import "sip" not found!
# 40090 INFO: Performing binary vs. data reclassification (3067 entries)
# 40855 INFO: Looking for ctypes DLLs
# 40949 INFO: Analyzing run-time hooks ...
# 40959 INFO: Including run-time hook 'pyi_rth_pkgres.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/rthooks'
# 40964 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/rthooks'
# 40966 INFO: Including run-time hook 'pyi_rth_setuptools.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/rthooks'
# 40967 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/rthooks'
# 40969 INFO: Including run-time hook 'pyi_rth_inspect.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/rthooks'
# 40972 INFO: Including run-time hook 'pyi_rth_pyqt5.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/rthooks'
# 40974 INFO: Processing pre-find-module-path hook 'hook-_pyi_rth_utils.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks/pre_find_module_path'
# 40975 INFO: Processing standard module hook 'hook-_pyi_rth_utils.py' from '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/hooks'
# 41080 INFO: Creating base_library.zip...
# 41124 INFO: Looking for dynamic libraries
# 45333 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/lib/libQt5Multimedia.so.5'.
# 45333 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/lib/libQt5MultimediaGstTools.so.5'.
# 45333 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/lib/libQt5MultimediaQuick.so.5'.
# 45333 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/lib/libQt5MultimediaWidgets.so.5'.
# 45334 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/audio/libqtaudio_alsa.so'.
# 45334 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/audio/libqtmedia_pulse.so'.
# 45334 WARNING: Library not found: could not resolve 'libQt53DCore.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/geometryloaders/libdefaultgeometryloader.so'.
# 45334 WARNING: Library not found: could not resolve 'libQt53DRender.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/geometryloaders/libdefaultgeometryloader.so'.
# 45334 WARNING: Library not found: could not resolve 'libQt53DCore.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/geometryloaders/libgltfgeometryloader.so'.
# 45334 WARNING: Library not found: could not resolve 'libQt53DRender.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/geometryloaders/libgltfgeometryloader.so'.
# 45334 WARNING: Library not found: could not resolve 'libQt5Pdf.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/imageformats/libqpdf.so'.
# 45334 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/mediaservice/libgstaudiodecoder.so'.
# 45334 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/mediaservice/libgstcamerabin.so'.
# 45334 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/mediaservice/libgstmediacapture.so'.
# 45334 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/mediaservice/libgstmediaplayer.so'.
# 45334 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/playlistformats/libqtmultimedia_m3u.so'.
# 45334 WARNING: Library not found: could not resolve 'libQt53DCore.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/renderers/libopenglrenderer.so'.
# 45334 WARNING: Library not found: could not resolve 'libQt53DRender.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/renderers/libopenglrenderer.so'.
# 45334 WARNING: Library not found: could not resolve 'libQt53DQuickScene2D.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/renderplugins/libscene2d.so'.
# 45334 WARNING: Library not found: could not resolve 'libQt53DLogic.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/renderplugins/libscene2d.so'.
# 45334 WARNING: Library not found: could not resolve 'libQt53DQuick.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/renderplugins/libscene2d.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DExtras.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/renderplugins/libscene2d.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt5Gamepad.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/renderplugins/libscene2d.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DCore.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/renderplugins/libscene2d.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DRender.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/renderplugins/libscene2d.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DInput.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/renderplugins/libscene2d.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DAnimation.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libassimpsceneimport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DLogic.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libassimpsceneimport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DExtras.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libassimpsceneimport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt5Gamepad.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libassimpsceneimport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DCore.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libassimpsceneimport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DRender.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libassimpsceneimport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DInput.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libassimpsceneimport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DLogic.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneexport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DExtras.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneexport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt5Gamepad.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneexport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DCore.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneexport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DRender.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneexport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DInput.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneexport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DLogic.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneimport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DExtras.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneimport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt5Gamepad.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneimport.so'.
# 45335 WARNING: Library not found: could not resolve 'libQt53DCore.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneimport.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DRender.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneimport.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DInput.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneimport.so'.
# 45336 WARNING: Library not found: could not resolve 'libspeechd.so.2', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/texttospeech/libqtexttospeech_speechd.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt5WebEngine.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/webview/libqtwebview_webengine.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt5WebEngineCore.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/plugins/webview/libqtwebview_webengine.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt5Bodymovin.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/Qt/labs/lottieqt/liblottieqtplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtMultimedia/libdeclarative_multimedia.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt5Pdf.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Pdf/libpdfplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DQuickScene2D.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene2D/libqtquickscene2dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DLogic.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene2D/libqtquickscene2dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DQuick.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene2D/libqtquickscene2dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt5Gamepad.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene2D/libqtquickscene2dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DCore.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene2D/libqtquickscene2dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DRender.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene2D/libqtquickscene2dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DInput.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene2D/libqtquickscene2dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DAnimation.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene3D/libqtquickscene3dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DLogic.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene3D/libqtquickscene3dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt5Gamepad.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene3D/libqtquickscene3dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DCore.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene3D/libqtquickscene3dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DRender.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene3D/libqtquickscene3dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libQt53DInput.so.5', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/Qt5/qml/QtQuick/Scene3D/libqtquickscene3dplugin.so'.
# 45336 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/QtMultimedia.abi3.so'.
# 45336 WARNING: Library not found: could not resolve 'libpulse-mainloop-glib.so.0', dependency of '/content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/QtMultimediaWidgets.abi3.so'.
# 45421 INFO: Warnings written to /content/linux_ai_terminal_assistant/build/Linux AI Assistant/warn-Linux AI Assistant.txt
# 45535 INFO: Graph cross-reference written to /content/linux_ai_terminal_assistant/build/Linux AI Assistant/xref-Linux AI Assistant.html
# 45711 INFO: checking PYZ
# 45732 INFO: Building because /content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyQt5/__init__.py changed
# 45732 INFO: Building PYZ (ZlibArchive) /content/linux_ai_terminal_assistant/build/Linux AI Assistant/PYZ-00.pyz
# 47882 INFO: Building PYZ (ZlibArchive) /content/linux_ai_terminal_assistant/build/Linux AI Assistant/PYZ-00.pyz completed successfully.
# 47952 INFO: checking PKG
# 47954 INFO: Building because /content/linux_ai_terminal_assistant/build/Linux AI Assistant/PYZ-00.pyz changed
# 47954 INFO: Building PKG (CArchive) Linux AI Assistant.pkg
# 48050 INFO: Building PKG (CArchive) Linux AI Assistant.pkg completed successfully.
# 48051 INFO: Bootloader /content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 48051 INFO: checking EXE
# 48053 INFO: Building because /content/linux_ai_terminal_assistant/venv/lib/python3.11/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run changed
# 48053 INFO: Building EXE from EXE-00.toc
# 48054 INFO: Copying bootloader EXE to /content/linux_ai_terminal_assistant/build/Linux AI Assistant/Linux AI Assistant
# 48054 INFO: Appending PKG archive to custom ELF section in EXE
# 48153 INFO: Building EXE from EXE-00.toc completed successfully.
# 48190 INFO: checking COLLECT
# 48251 INFO: Removing dir /content/linux_ai_terminal_assistant/dist/Linux AI Assistant
# 48411 INFO: Building COLLECT COLLECT-00.toc
# 52509 INFO: Executing: strip /root/.cache/pyinstaller/bincache10py31164bit/libpython3.11.so.1.0
# 55394 INFO: Building COLLECT COLLECT-00.toc completed successfully.
# 55477 INFO: Build complete! The results are available in: /content/linux_ai_terminal_assistant/dist
#
#
# Zakończono budowanie z PyInstaller. Sprawdź katalog 'dist'.
#
# Sprawdzanie zawartości katalogu PyInstallera (dist):
#    660575      4 drwxr-xr-x   3 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant
#    668346     12 drwxr-xr-x  24 root     root        12288 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal
#    684640    236 -rwxr-xr-x   1 root     root       239712 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libFLAC.so.8
#    687786      0 lrwxrwxrwx   1 root     root           28 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Nfc.so.5 -> PyQt5/Qt5/lib/libQt5Nfc.so.5
#    687753      0 lrwxrwxrwx   1 root     root           28 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Gui.so.5 -> PyQt5/Qt5/lib/libQt5Gui.so.5
#    687735      4 drwxr-xr-x   3 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/attrs-25.3.0.dist-info
#    684608    232 -rwxr-xr-x   1 root     root       235592 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libpng16.so.16
#    687796      0 lrwxrwxrwx   1 root     root           29 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Help.so.5 -> PyQt5/Qt5/lib/libQt5Help.so.5
#    684662     48 -rwxr-xr-x   1 root     root        47688 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libffi.so.8
#    684644    516 -rwxr-xr-x   1 root     root       526384 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgstaudio-1.0.so.0
#    687775      0 lrwxrwxrwx   1 root     root           38 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5WaylandClient.so.5 -> PyQt5/Qt5/lib/libQt5WaylandClient.so.5
#    687777      0 lrwxrwxrwx   1 root     root           31 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5XcbQpa.so.5 -> PyQt5/Qt5/lib/libQt5XcbQpa.so.5
#    684618     80 -rwxr-xr-x   1 root     root        81640 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libXext.so.6
#    687782      0 lrwxrwxrwx   1 root     root           35 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5WebChannel.so.5 -> PyQt5/Qt5/lib/libQt5WebChannel.so.5
#    687731      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/MarkupSafe-3.0.2.dist-info
#    687781      0 lrwxrwxrwx   1 root     root           37 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5TextToSpeech.so.5 -> PyQt5/Qt5/lib/libQt5TextToSpeech.so.5
#    684728    628 -rwxr-xr-x   1 root     root       641128 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libcups.so.2
#    684558   2208 -rwxr-xr-x   1 root     root      2260296 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libstdc++.so.6
#    684566    332 -rwxr-xr-x   1 root     root       338648 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgssapi_krb5.so.2
#    684588     52 -rwxr-xr-x   1 root     root        52016 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libkrb5support.so.0
#    684742   4352 -rwxr-xr-x   1 root     root      4455728 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libcrypto.so.3
#    687797      0 lrwxrwxrwx   1 root     root           37 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5QuickWidgets.so.5 -> PyQt5/Qt5/lib/libQt5QuickWidgets.so.5
#    684508      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/multidict
#    687746      0 lrwxrwxrwx   1 root     root           32 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Network.so.5 -> PyQt5/Qt5/lib/libQt5Network.so.5
#    684621    176 -rwxr-xr-x   1 root     root       178248 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libvorbis.so.0
#    684578   1268 -rwxr-xr-x   1 root     root      1296312 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgcrypt.so.20
#    684738    368 -rwxr-xr-x   1 root     root       376512 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libldap-2.5.so.0
#    684630    528 -rwxr-xr-x   1 root     root       538960 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libpulsecommon-15.99.so
#    687780      0 lrwxrwxrwx   1 root     root           32 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Sensors.so.5 -> PyQt5/Qt5/lib/libQt5Sensors.so.5
#    684586    812 -rwxr-xr-x   1 root     root       827936 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libkrb5.so.3
#    687761      0 lrwxrwxrwx   1 root     root           41 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5PositioningQuick.so.5 -> PyQt5/Qt5/lib/libQt5PositioningQuick.so.5
#    684718   1256 -rwxr-xr-x   1 root     root      1285888 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libp11-kit.so.0
#    668352      4 drwxr-xr-x   6 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/PyQt5
#    687793      0 lrwxrwxrwx   1 root     root           32 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Quick3D.so.5 -> PyQt5/Qt5/lib/libQt5Quick3D.so.5
#    684648   1340 -rwxr-xr-x   1 root     root      1371192 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgstreamer-1.0.so.0
#    684724     76 -rwxr-xr-x   1 root     root        76112 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libavahi-client.so.3
#    687774      0 lrwxrwxrwx   1 root     root           47 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5EglFSDeviceIntegration.so.5 -> PyQt5/Qt5/lib/libQt5EglFSDeviceIntegration.so.5
#    684732    428 -rwxr-xr-x   1 root     root       435216 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libodbc.so.2
#    684694     32 -rwxr-xr-x   1 root     root        31096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-util.so.1
#    684486      4 drwxr-xr-x   3 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/google
#    684570   1248 -rwxr-xr-x   1 root     root      1277712 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libglib-2.0.so.0
#    687131      4 drwxr-xr-x   3 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/_internal
#    684658    532 -rwxr-xr-x   1 root     root       542128 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgstbase-1.0.so.0
#    684740     64 -rwxr-xr-x   1 root     root        63992 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/liblber-2.5.so.0
#    687778      0 lrwxrwxrwx   1 root     root           35 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5SerialPort.so.5 -> PyQt5/Qt5/lib/libQt5SerialPort.so.5
#    687729      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/httplib2
#    687768      0 lrwxrwxrwx   1 root     root           37 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Quick3DUtils.so.5 -> PyQt5/Qt5/lib/libQt5Quick3DUtils.so.5
#    684603     88 -rwxr-xr-x   1 root     root        89096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libbsd.so.0
#    684714   1704 -rwxr-xr-x   1 root     root      1743016 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libunistring.so.2
#    684660    268 -rwxr-xr-x   1 root     root       272200 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgstpbutils-1.0.so.0
#    687762      0 lrwxrwxrwx   1 root     root           42 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5MultimediaWidgets.so.5 -> PyQt5/Qt5/lib/libQt5MultimediaWidgets.so.5
#    684702     40 -rwxr-xr-x   1 root     root        39864 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxkbcommon-x11.so.0
#    687769      0 lrwxrwxrwx   1 root     root           40 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5QuickTemplates2.so.5 -> PyQt5/Qt5/lib/libQt5QuickTemplates2.so.5
#    684642     16 -rwxr-xr-x   1 root     root        14048 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libX11-xcb.so.1
#    684572     24 -rwxr-xr-x   1 root     root        22600 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libkeyutils.so.1
#    687770      0 lrwxrwxrwx   1 root     root           29 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Test.so.5 -> PyQt5/Qt5/lib/libQt5Test.so.5
#    684672   1032 -rwxr-xr-x   1 root     root      1055472 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libasound.so.2
#    684626    680 -rwxr-xr-x   1 root     root       694408 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libvorbisenc.so.2
#    687798      0 lrwxrwxrwx   1 root     root           34 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5X11Extras.so.5 -> PyQt5/Qt5/lib/libQt5X11Extras.so.5
#    687137    156 -rw-r--r--   1 root     root       156295 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/app_icon.png
#    684620    292 -rwxr-xr-x   1 root     root       298120 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libfontconfig.so.1
#    687794      0 lrwxrwxrwx   1 root     root           34 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5QuickTest.so.5 -> PyQt5/Qt5/lib/libQt5QuickTest.so.5
#    684748    112 -rwxr-xr-x   1 root     root       112856 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-glx.so.0
#    684595     28 -rwxr-xr-x   1 root     root        26800 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libXdmcp.so.6
#    684564    180 -rwxr-xr-x   1 root     root       182864 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libk5crypto.so.3
#    684530      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/pydantic_core
#    687779      0 lrwxrwxrwx   1 root     root           37 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5PrintSupport.so.5 -> PyQt5/Qt5/lib/libQt5PrintSupport.so.5
#    684577     20 -rwxr-xr-x   1 root     root        18504 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libcom_err.so.2
#    687791      0 lrwxrwxrwx   1 root     root           36 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5QuickShapes.so.5 -> PyQt5/Qt5/lib/libQt5QuickShapes.so.5
#    687757      0 lrwxrwxrwx   1 root     root           28 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Qml.so.5 -> PyQt5/Qt5/lib/libQt5Qml.so.5
#    684518      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/frozenlist
#    684722    516 -rwxr-xr-x   1 root     root       526896 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgmp.so.10
#    684500      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/yarl
#    684582     16 -rwxr-xr-x   1 root     root        14488 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgthread-2.0.so.0
#    684726     92 -rwxr-xr-x   1 root     root        92312 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libtasn1.so.6
#    684646    784 -rwxr-xr-x   1 root     root       801240 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgstvideo-1.0.so.0
#    684680     24 -rwxr-xr-x   1 root     root        22864 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-render-util.so.0
#    687754      0 lrwxrwxrwx   1 root     root           28 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Xml.so.5 -> PyQt5/Qt5/lib/libQt5Xml.so.5
#    684710     52 -rwxr-xr-x   1 root     root        51648 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libavahi-common.so.3
#    684560    168 -rwxr-xr-x   1 root     root       170456 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/liblzma.so.5
#    684512      4 drwxr-xr-x   3 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/aiohttp
#    687766      0 lrwxrwxrwx   1 root     root           45 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Quick3DRuntimeRender.so.5 -> PyQt5/Qt5/lib/libQt5Quick3DRuntimeRender.so.5
#    684706     20 -rwxr-xr-x   1 root     root        18688 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-image.so.0
#    687138      4 drwxr-xr-x   3 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/src
#    687773      0 lrwxrwxrwx   1 root     root           43 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5MultimediaGstTools.so.5 -> PyQt5/Qt5/lib/libQt5MultimediaGstTools.so.5
#    684627    336 -rwxr-xr-x   1 root     root       343240 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libpulse.so.0
#    684536      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/markupsafe
#    684562     40 -rwxr-xr-x   1 root     root        39024 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libcap.so.2
#    687785      0 lrwxrwxrwx   1 root     root           40 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5MultimediaQuick.so.5 -> PyQt5/Qt5/lib/libQt5MultimediaQuick.so.5
# ...
#    684668     24 -rwxr-xr-x   1 root     root        23056 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgstallocators-1.0.so.0
#    687545      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/google_api_python_client-2.170.0.dist-info
#    684636    500 -rwxr-xr-x   1 root     root       508456 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libsndfile.so.1
#    684664    528 -rwxr-xr-x   1 root     root       540632 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/liborc-0.4.so.0
#    684734     40 -rwxr-xr-x   1 root     root        39384 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libltdl.so.7
#    684632     40 -rwxr-xr-x   1 root     root        38872 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libogg.so.0
#    687784      0 lrwxrwxrwx   1 root     root           34 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Bluetooth.so.5 -> PyQt5/Qt5/lib/libQt5Bluetooth.so.5
#    684606     52 -rwxr-xr-x   1 root     root        51512 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libbrotlidec.so.1
#    684712    128 -rwxr-xr-x   1 root     root       129096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libidn2.so.0
#    687765      0 lrwxrwxrwx   1 root     root           38 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Quick3DRender.so.5 -> PyQt5/Qt5/lib/libQt5Quick3DRender.so.5
#    684638    372 -rwxr-xr-x   1 root     root       378952 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libopus.so.0
#    684692    116 -rwxr-xr-x   1 root     root       116984 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-xkb.so.1
#    687755      0 lrwxrwxrwx   1 root     root           32 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Widgets.so.5 -> PyQt5/Qt5/lib/libQt5Widgets.so.5
#    687150      4 drwxr-xr-x   3 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/setuptools
#    684591    148 -rwxr-xr-x   1 root     root       149760 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgpg-error.so.0
#    684708     16 -rwxr-xr-x   1 root     root        14488 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libXcomposite.so.1
#    684447      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/lib-dynload
#    684556    124 -rwxr-xr-x   1 root     root       125488 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgcc_s.so.1
#    687792      0 lrwxrwxrwx   1 root     root           36 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5XmlPatterns.so.5 -> PyQt5/Qt5/lib/libQt5XmlPatterns.so.5
#    684700     16 -rwxr-xr-x   1 root     root        14552 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-shape.so.0
#    687760      0 lrwxrwxrwx   1 root     root           34 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5QmlModels.so.5 -> PyQt5/Qt5/lib/libQt5QmlModels.so.5
#    684492      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/charset_normalizer
#    687756      0 lrwxrwxrwx   1 root     root           28 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Sql.so.5 -> PyQt5/Qt5/lib/libQt5Sql.so.5
#    684576    824 -rwxr-xr-x   1 root     root       841808 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libzstd.so.1
#    684690     72 -rwxr-xr-x   1 root     root        71912 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-randr.so.0
#    684656     64 -rwxr-xr-x   1 root     root        63744 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libunwind.so.8
#    687789      0 lrwxrwxrwx   1 root     root           39 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5QuickControls2.so.5 -> PyQt5/Qt5/lib/libQt5QuickControls2.so.5
#    684613    192 -rwxr-xr-x   1 root     root       194872 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libexpat.so.1
#    684674     76 -rwxr-xr-x   1 root     root        74848 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libbz2.so.1.0
#    684666    264 -rwxr-xr-x   1 root     root       267192 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgsttag-1.0.so.0
#    684446   7600 -rwxr-xr-x   1 root     root      7781072 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libpython3.11.so.1.0
#    687748      0 lrwxrwxrwx   1 root     root           30 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libicudata.so.56 -> PyQt5/Qt5/lib/libicudata.so.56
#    684602     48 -rwxr-xr-x   1 root     root        47472 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libmd.so.0
#    684480      4 drwxr-xr-x   3 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/grpc
#    684652     24 -rwxr-xr-x   1 root     root        22736 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgmodule-2.0.so.0
#    684612     32 -rwxr-xr-x   1 root     root        30936 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libuuid.so.1
#    684684     36 -rwxr-xr-x   1 root     root        35032 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-xfixes.so.0
#    684752    332 -rwxr-xr-x   1 root     root       335936 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libreadline.so.8
#    684571    308 -rwxr-xr-x   1 root     root       313656 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libdbus-1.so.3
#    687767      0 lrwxrwxrwx   1 root     root           43 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Quick3DAssetImport.so.5 -> PyQt5/Qt5/lib/libQt5Quick3DAssetImport.so.5
#    687750      0 lrwxrwxrwx   1 root     root           35 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Concurrent.so.5 -> PyQt5/Qt5/lib/libQt5Concurrent.so.5
#    687758      0 lrwxrwxrwx   1 root     root           36 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Positioning.so.5 -> PyQt5/Qt5/lib/libQt5Positioning.so.5
#    684504      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/propcache
#    684688     36 -rwxr-xr-x   1 root     root        35064 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-sync.so.1
#    684682     16 -rwxr-xr-x   1 root     root        14488 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-keysyms.so.1
#    687764      0 lrwxrwxrwx   1 root     root           31 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5OpenGL.so.5 -> PyQt5/Qt5/lib/libQt5OpenGL.so.5
#    684678    280 -rwxr-xr-x   1 root     root       285232 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxkbcommon.so.0
#    684583    792 -rwxr-xr-x   1 root     root       807936 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libsystemd.so.0
#    684609    796 -rwxr-xr-x   1 root     root       813128 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libfreetype.so.6
#    687776      0 lrwxrwxrwx   1 root     root           35 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5WebSockets.so.5 -> PyQt5/Qt5/lib/libQt5WebSockets.so.5
#    684736    104 -rwxr-xr-x   1 root     root       105392 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libsasl2.so.2
#    687749      0 lrwxrwxrwx   1 root     root           29 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5DBus.so.5 -> PyQt5/Qt5/lib/libQt5DBus.so.5
#    684720    276 -rwxr-xr-x   1 root     root       281000 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libnettle.so.8
#    684598   1276 -rwxr-xr-x   1 root     root      1306280 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libX11.so.6
#    684634     28 -rwxr-xr-x   1 root     root        26616 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libasyncns.so.0
#    684624     80 -rwxr-xr-x   1 root     root        80768 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libapparmor.so.1
#    684704     24 -rwxr-xr-x   1 root     root        22616 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-icccm.so.4
#    684568    108 -rwxr-xr-x   1 root     root       108936 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libz.so.1
#    684676    688 -rwxr-xr-x   1 root     root       700800 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libdw.so.1
#    684670    116 -rwxr-xr-x   1 root     root       117400 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libelf.so.1
#    684599     20 -rwxr-xr-x   1 root     root        18720 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libXau.so.6
#    687759      0 lrwxrwxrwx   1 root     root           30 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Quick.so.5 -> PyQt5/Qt5/lib/libQt5Quick.so.5
#    687745   1412 -rw-r--r--   1 root     root      1443550 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/base_library.zip
#    684686     56 -rwxr-xr-x   1 root     root        55544 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-render.so.0
#    684654     84 -rwxr-xr-x   1 root     root        85592 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgstapp-1.0.so.0
#    687747      0 lrwxrwxrwx   1 root     root           28 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libicuuc.so.56 -> PyQt5/Qt5/lib/libicuuc.so.56
#    687787      0 lrwxrwxrwx   1 root     root           38 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5RemoteObjects.so.5 -> PyQt5/Qt5/lib/libQt5RemoteObjects.so.5
#    684616    136 -rwxr-xr-x   1 root     root       137560 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libbrotlicommon.so.1
#    684590    468 -rwxr-xr-x   1 root     root       477296 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libpcre.so.3
#    687771      0 lrwxrwxrwx   1 root     root           33 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Location.so.5 -> PyQt5/Qt5/lib/libQt5Location.so.5
#    687783      0 lrwxrwxrwx   1 root     root           32 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5WebView.so.5 -> PyQt5/Qt5/lib/libQt5WebView.so.5
#    684716    284 -rwxr-xr-x   1 root     root       289800 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libhogweed.so.6
#    687788      0 lrwxrwxrwx   1 root     root           40 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5QmlWorkerScript.so.5 -> PyQt5/Qt5/lib/libQt5QmlWorkerScript.so.5
#    687175      4 drwxr-xr-x   3 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/googleapiclient
#    684696     16 -rwxr-xr-x   1 root     root        14552 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-xinerama.so.0
#    684746    336 -rwxr-xr-x   1 root     root       342200 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libpq.so.5
#    684650    380 -rwxr-xr-x   1 root     root       387464 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgobject-2.0.so.0
#    687763      0 lrwxrwxrwx   1 root     root           35 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Multimedia.so.5 -> PyQt5/Qt5/lib/libQt5Multimedia.so.5
#    684698     16 -rwxr-xr-x   1 root     root        14568 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libxcb-shm.so.0
#    684744    656 -rwxr-xr-x   1 root     root       667864 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libssl.so.3
#    687165      4 drwxr-xr-x   2 root     root         4096 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/google_api_core-2.25.0rc1.dist-info
#    687752      0 lrwxrwxrwx   1 root     root           29 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Core.so.5 -> PyQt5/Qt5/lib/libQt5Core.so.5
#    687772      0 lrwxrwxrwx   1 root     root           28 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Svg.so.5 -> PyQt5/Qt5/lib/libQt5Svg.so.5
#    684730   1956 -rwxr-xr-x   1 root     root      2000320 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libgnutls.so.30
#    687790      0 lrwxrwxrwx   1 root     root           39 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5QuickParticles.so.5 -> PyQt5/Qt5/lib/libQt5QuickParticles.so.5
#    687795      0 lrwxrwxrwx   1 root     root           33 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libQt5Designer.so.5 -> PyQt5/Qt5/lib/libQt5Designer.so.5
#    660579  11380 -rwxr-xr-x   1 root     root     11650080 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/Linux\ AI\ Assistant
#
# W poszukiwaniu libpython w '/content/linux_ai_terminal_assistant/dist/Linux AI Assistant':
#    684446   7600 -rwxr-xr-x   1 root     root      7781072 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/libpython3.11.so.1.0
#
# W poszukiwaniu Lorem ipsum.txt w '/content/linux_ai_terminal_assistant/dist/Linux AI Assistant/_internal':
#    687136      4 -rw-r--r--   1 root     root         1335 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/_internal/setuptools/_vendor/jaraco/text/Lorem\ ipsum.txt
#    687162      4 -rw-r--r--   1 root     root         1335 May 23 22:16 /content/linux_ai_terminal_assistant/dist/Linux\ AI\ Assistant/_internal/setuptools/_vendor/jaraco/text/Lorem\ ipsum.txt

# %%
# Komórka 7: Tworzenie struktury AppDir i kopiowanie plików z PyInstallera
import os
import shutil
import subprocess

# Upewnij się, że zmienne globalne są zdefiniowane (powinny być z Komórki 4)
# COLAB_CONTENT_DIR, APPDIR_FULL_PATH, PYINSTALLER_DIST_DIR_FULL_PATH,
# APP_EXECUTABLE_NAME_FROM_PYINSTALLER, APP_EXECUTABLE_NAME_IN_APPDIR_ROOT,
# ICON_DESKTOP_ENTRY_NAME, ICON_APPDIR_TOPLEVEL_FILENAME, ICON_SOURCE_PATH

# Przejdź do katalogu /content, aby AppDir było tworzone na tym samym poziomie
if os.getcwd() != COLAB_CONTENT_DIR:
    print(f"Zmieniam katalog na: {COLAB_CONTENT_DIR} (był: {os.getcwd()})")
    os.chdir(COLAB_CONTENT_DIR)
else:
    print(f"Już jestem w katalogu: {COLAB_CONTENT_DIR}")

# Usuń stary AppDir, jeśli istnieje, i utwórz go na nowo
if os.path.isdir(APPDIR_FULL_PATH):
    print(f"Usuwanie istniejącego katalogu AppDir: {APPDIR_FULL_PATH}...")
    shutil.rmtree(APPDIR_FULL_PATH)
os.makedirs(APPDIR_FULL_PATH, exist_ok=True)
print(f"Utworzono czysty katalog AppDir: {APPDIR_FULL_PATH}")

# --- Kluczowy krok: Kopiowanie TYLKO zawartości z katalogu wyjściowego PyInstallera ---
print(f"\nKopiowanie zawartości z katalogu PyInstallera '{PYINSTALLER_DIST_DIR_FULL_PATH}' do korzenia AppDir '{APPDIR_FULL_PATH}'...")
if os.path.isdir(PYINSTALLER_DIST_DIR_FULL_PATH):
    # Kopiujemy każdy element z katalogu dystrybucyjnego PyInstallera do korzenia AppDir
    for item_name in os.listdir(PYINSTALLER_DIST_DIR_FULL_PATH):
        source_item_path = os.path.join(PYINSTALLER_DIST_DIR_FULL_PATH, item_name)
        destination_item_path = os.path.join(APPDIR_FULL_PATH, item_name)
        if os.path.isdir(source_item_path):
            print(f"  Kopiowanie katalogu: {source_item_path} -> {destination_item_path}")
            shutil.copytree(source_item_path, destination_item_path, dirs_exist_ok=True)
        else:
            print(f"  Kopiowanie pliku: {source_item_path} -> {destination_item_path}")
            shutil.copy2(source_item_path, destination_item_path)
    print("Zawartość katalogu PyInstallera skopiowana.")

    # Zmiana nazwy głównego pliku wykonywalnego w AppDir, jeśli trzeba
    source_exe_in_appdir = os.path.join(APPDIR_FULL_PATH, APP_EXECUTABLE_NAME_FROM_PYINSTALLER)
    target_exe_in_appdir = os.path.join(APPDIR_FULL_PATH, APP_EXECUTABLE_NAME_IN_APPDIR_ROOT)

    if APP_EXECUTABLE_NAME_FROM_PYINSTALLER != APP_EXECUTABLE_NAME_IN_APPDIR_ROOT:
        if os.path.exists(source_exe_in_appdir):
            print(f"Zmieniam nazwę pliku wykonywalnego w AppDir: '{source_exe_in_appdir}' -> '{target_exe_in_appdir}'")
            os.rename(source_exe_in_appdir, target_exe_in_appdir)
        elif not os.path.exists(target_exe_in_appdir):
             print(f"OSTRZEŻENIE: Plik '{source_exe_in_appdir}' nie istnieje w AppDir, a docelowy '{target_exe_in_appdir}' też nie.")

    if not os.path.exists(target_exe_in_appdir):
         print(f"BŁĄD KRYTYCZNY: Główny plik wykonywalny '{target_exe_in_appdir}' nie istnieje w AppDir po kopiowaniu/zmianie nazwy!")
    else:
        print(f"Główny plik wykonywalny poprawnie umieszczony w AppDir: {target_exe_in_appdir}")

        # Poprawka dla libpython (kopiowanie, jeśli PyInstaller spakował bez .1.0)
        print("\nSprawdzanie i przygotowywanie libpython...")
        internal_dir_in_appdir = os.path.join(APPDIR_FULL_PATH, "_internal") # PyInstaller tworzy _internal
        if os.path.isdir(internal_dir_in_appdir): # _internal powinno być skopiowane z dist/
            # Ustal wersję Pythona dynamicznie
            python_major_minor = f"{sys.version_info.major}.{sys.version_info.minor}"
            libpython_packed_name = f"libpython{python_major_minor}.so"
            libpython_expected_name = f"{libpython_packed_name}.1.0"

            libpython_packed_path = os.path.join(internal_dir_in_appdir, libpython_packed_name)
            libpython_expected_path = os.path.join(internal_dir_in_appdir, libpython_expected_name)

            if os.path.exists(libpython_packed_path) and not os.path.lexists(libpython_expected_path):
                print(f"Kopiowanie '{libpython_packed_path}' do '{libpython_expected_path}'...")
                shutil.copy2(libpython_packed_path, libpython_expected_path)
                print(f"Plik libpython skopiowany jako '{libpython_expected_path}'.")
            elif not os.path.exists(libpython_packed_path) and os.path.exists(libpython_expected_path):
                 print(f"Oczekiwany plik '{libpython_expected_path}' już istnieje; spakowany '{libpython_packed_name}' nie jest potrzebny do kopiowania.")
            elif not os.path.exists(libpython_packed_path) and not os.path.exists(libpython_expected_path):
                print(f"OSTRZEŻENIE: Ani '{libpython_packed_path}' ani '{libpython_expected_path}' nie znaleziono w '{internal_dir_in_appdir}'. Sprawdź output PyInstallera.")
            else:
                print(f"Plik libpython ('{libpython_expected_path}' lub '{libpython_packed_name}') wydaje się być poprawnie obecny w _internal.")
        else:
            print(f"OSTRZEŻENIE: Katalog '{internal_dir_in_appdir}' nie istnieje w AppDir. To jest nietypowe po skopiowaniu z PyInstallera. Pomijam operacje na libpython.")
else:
    print(f"BŁĄD KRYTYCZNY: Katalog wyjściowy PyInstallera '{PYINSTALLER_DIST_DIR_FULL_PATH}' nie istnieje. Przebuduj aplikację za pomocą PyInstallera (Komórka 6).")
    raise FileNotFoundError(f"Katalog PyInstallera nie znaleziony: {PYINSTALLER_DIST_DIR_FULL_PATH}")

# --- Tworzenie standardowej struktury AppDir (usr/bin, usr/share, etc.) ---
# Te katalogi są tworzone wewnątrz APPDIR_FULL_PATH
print("\nTworzenie standardowej struktury katalogów w AppDir...")
os.makedirs(os.path.join(APPDIR_FULL_PATH, "usr", "bin"), exist_ok=True)
os.makedirs(os.path.join(APPDIR_FULL_PATH, "usr", "lib"), exist_ok=True)
os.makedirs(os.path.join(APPDIR_FULL_PATH, "usr", "share", "applications"), exist_ok=True)
os.makedirs(os.path.join(APPDIR_FULL_PATH, "usr", "share", "icons", "hicolor", "256x256", "apps"), exist_ok=True)
print("Standardowa struktura AppDir utworzona.")


# --- Tworzenie pliku .desktop ---
print("\nTworzenie pliku .desktop...")
# Plik .desktop na najwyższym poziomie AppDir
DESKTOP_FILE_PATH_IN_APPDIR_ROOT = os.path.join(APPDIR_FULL_PATH, f"{ICON_DESKTOP_ENTRY_NAME}.desktop")
# Plik .desktop w standardowej lokalizacji AppDir/usr/share/applications/
DESKTOP_FILE_PATH_USR = os.path.join(APPDIR_FULL_PATH, "usr", "share", "applications", f"{ICON_DESKTOP_ENTRY_NAME}.desktop")

DESKTOP_FILE_CONTENT = f"""[Desktop Entry]
Version=1.0
Name=Linux AI Assistant
GenericName=AI Command Assistant
Comment=AI Assistant for Linux Commands
Exec={APP_EXECUTABLE_NAME_IN_APPDIR_ROOT}
Icon={ICON_DESKTOP_ENTRY_NAME}
Terminal=false
Type=Application
Categories=Utility;Development;System;
StartupWMClass=Linux AI Assistant
"""
with open(DESKTOP_FILE_PATH_IN_APPDIR_ROOT, "w") as f: f.write(DESKTOP_FILE_CONTENT)
# Kopiowanie pliku .desktop do standardowej lokalizacji w AppDir
shutil.copy2(DESKTOP_FILE_PATH_IN_APPDIR_ROOT, DESKTOP_FILE_PATH_USR)
print(f"Plik .desktop utworzony w '{DESKTOP_FILE_PATH_IN_APPDIR_ROOT}' i skopiowany do '{DESKTOP_FILE_PATH_USR}'.")

# --- Przygotowanie ikon ---
print("\nPrzygotowywanie ikon...")
ICON_DEST_SYSTEM_PATH = os.path.join(APPDIR_FULL_PATH, "usr", "share", "icons", "hicolor", "256x256", "apps", f"{ICON_DESKTOP_ENTRY_NAME}.png")
ICON_DEST_TOPLEVEL_PATH = os.path.join(APPDIR_FULL_PATH, ICON_APPDIR_TOPLEVEL_FILENAME) # np. linux-ai-assistant.png w korzeniu AppDir

if os.path.exists(ICON_SOURCE_PATH):
    shutil.copy2(ICON_SOURCE_PATH, ICON_DEST_SYSTEM_PATH)
    shutil.copy2(ICON_SOURCE_PATH, ICON_DEST_TOPLEVEL_PATH)
    print(f"Ikona skopiowana do '{ICON_DEST_SYSTEM_PATH}' oraz '{ICON_DEST_TOPLEVEL_PATH}'.")

    # Utwórz dowiązanie .DirIcon, jeśli nazwa pliku ikony na najwyższym poziomie różni się od ICON_DESKTOP_ENTRY_NAME.png
    # lub jeśli po prostu chcemy mieć .DirIcon wskazujące na naszą główną ikonę.
    dir_icon_link_path = os.path.join(APPDIR_FULL_PATH, ".DirIcon")
    if not os.path.lexists(dir_icon_link_path):
         # Tworzymy dowiązanie w bieżącym katalogu, więc musimy być w APPDIR_FULL_PATH
        if os.getcwd() != APPDIR_FULL_PATH:
            print(f"Zmieniam katalog na {APPDIR_FULL_PATH} przed utworzeniem .DirIcon")
            os.chdir(APPDIR_FULL_PATH)
        print(f"Tworzenie dowiązania .DirIcon -> {ICON_APPDIR_TOPLEVEL_FILENAME}")
        subprocess.run(["ln", "-sf", ICON_APPDIR_TOPLEVEL_FILENAME, ".DirIcon"], check=False)
    print("Ikony przygotowane.")
else:
    print(f"OSTRZEŻENIE: Plik ikony źródłowej '{ICON_SOURCE_PATH}' nie znaleziony. Ikony nie zostały skopiowane.")

# --- Tworzenie pliku AppRun ---
print("\nTworzenie pliku AppRun...")
APP_RUN_PATH = os.path.join(APPDIR_FULL_PATH, "AppRun")
APP_RUN_CONTENT = f"""#!/bin/bash
APPDIR=$(dirname "$(readlink -f "$0")")
cd "$APPDIR"

# Dodajemy ścieżki do bibliotek i modułów Pythona wewnątrz AppDir
# _internal jest tam, gdzie PyInstaller umieszcza wiele rzeczy, w tym libpython
# Zakładamy, że wszystkie zależności Pythona są w _internal lub w strukturze PyQt5/_internal
export LD_LIBRARY_PATH="$APPDIR/_internal":"$APPDIR/_internal/PyQt5/Qt5/lib${{LD_LIBRARY_PATH:+:$LD_LIBRARY_PATH}}"
export PYTHONPATH="$APPDIR/_internal":"$APPDIR/_internal/src${{PYTHONPATH:+:$PYTHONPATH}}" # src jest wewnątrz _internal po add-data
export QT_PLUGIN_PATH="$APPDIR/_internal/PyQt5/Qt5/plugins${{QT_PLUGIN_PATH:+:$QT_PLUGIN_PATH}}"
export QT_QPA_PLATFORM_PLUGIN_PATH="$APPDIR/_internal/PyQt5/Qt5/plugins/platforms${{QT_QPA_PLATFORM_PLUGIN_PATH:+:$QT_QPA_PLATFORM_PLUGIN_PATH}}"

# Możesz odkomentować poniższe linie do debugowania zmiennych środowiskowych przy uruchamianiu AppImage
# echo "--- AppRun Debug ---" >&2
# echo "APPDIR: $APPDIR" >&2
# echo "LD_LIBRARY_PATH: $LD_LIBRARY_PATH" >&2
# echo "PYTHONPATH: $PYTHONPATH" >&2
# echo "QT_PLUGIN_PATH: $QT_PLUGIN_PATH" >&2
# echo "QT_QPA_PLATFORM_PLUGIN_PATH: $QT_QPA_PLATFORM_PLUGIN_PATH" >&2
# echo "PWD: $(pwd)" >&2
# echo "Uruchamianie: $APPDIR/{APP_EXECUTABLE_NAME_IN_APPDIR_ROOT}" >&2
# echo "--------------------" >&2

exec "$APPDIR/{APP_EXECUTABLE_NAME_IN_APPDIR_ROOT}" "$@"
"""
with open(APP_RUN_PATH, "w") as f: f.write(APP_RUN_CONTENT)
subprocess.run(["chmod", "+x", APP_RUN_PATH], check=True)
print("Plik AppRun utworzony.")

print(f"\n--- Zakończono przygotowywanie struktury {APPDIR_NAME} ---")
print(f"Zawartość korzenia {APPDIR_FULL_PATH}:")
# !ls -p "{APPDIR_FULL_PATH}"
if os.path.isdir(os.path.join(APPDIR_FULL_PATH, "_internal")):
    print(f"\nZawartość {os.path.join(APPDIR_FULL_PATH, '_internal')} (pierwsze 15 elementów):")
    # !ls -p "{os.path.join(APPDIR_FULL_PATH, '_internal')}" | head -n 15
# Out:
# Zmieniam katalog na: /content (był: /content/linux_ai_terminal_assistant)
# Usuwanie istniejącego katalogu AppDir: /content/LinuxAIAssistant.AppDir...
# Utworzono czysty katalog AppDir: /content/LinuxAIAssistant.AppDir
#
# Kopiowanie zawartości z katalogu PyInstallera '/content/linux_ai_terminal_assistant/dist/Linux AI Assistant' do korzenia AppDir '/content/LinuxAIAssistant.AppDir'...
#   Kopiowanie katalogu: /content/linux_ai_terminal_assistant/dist/Linux AI Assistant/_internal -> /content/LinuxAIAssistant.AppDir/_internal
#   Kopiowanie pliku: /content/linux_ai_terminal_assistant/dist/Linux AI Assistant/Linux AI Assistant -> /content/LinuxAIAssistant.AppDir/Linux AI Assistant
# Zawartość katalogu PyInstallera skopiowana.
# Zmieniam nazwę pliku wykonywalnego w AppDir: '/content/LinuxAIAssistant.AppDir/Linux AI Assistant' -> '/content/LinuxAIAssistant.AppDir/LinuxAIAssistant'
# Główny plik wykonywalny poprawnie umieszczony w AppDir: /content/LinuxAIAssistant.AppDir/LinuxAIAssistant
#
# Sprawdzanie i przygotowywanie libpython...
# Oczekiwany plik '/content/LinuxAIAssistant.AppDir/_internal/libpython3.11.so.1.0' już istnieje; spakowany 'libpython3.11.so' nie jest potrzebny do kopiowania.
#
# Tworzenie standardowej struktury katalogów w AppDir...
# Standardowa struktura AppDir utworzona.
#
# Tworzenie pliku .desktop...
# Plik .desktop utworzony w '/content/LinuxAIAssistant.AppDir/linux-ai-assistant.desktop' i skopiowany do '/content/LinuxAIAssistant.AppDir/usr/share/applications/linux-ai-assistant.desktop'.
#
# Przygotowywanie ikon...
# Ikona skopiowana do '/content/LinuxAIAssistant.AppDir/usr/share/icons/hicolor/256x256/apps/linux-ai-assistant.png' oraz '/content/LinuxAIAssistant.AppDir/linux-ai-assistant.png'.
# Zmieniam katalog na /content/LinuxAIAssistant.AppDir przed utworzeniem .DirIcon
# Tworzenie dowiązania .DirIcon -> linux-ai-assistant.png
# Ikony przygotowane.
#
# Tworzenie pliku AppRun...
# Plik AppRun utworzony.
#
# --- Zakończono przygotowywanie struktury LinuxAIAssistant.AppDir ---
# Zawartość korzenia /content/LinuxAIAssistant.AppDir:
# AppRun	    LinuxAIAssistant		linux-ai-assistant.png
# _internal/  linux-ai-assistant.desktop	usr/
#
# Zawartość /content/LinuxAIAssistant.AppDir/_internal (pierwsze 15 elementów):
# aiohttp/
# app_icon.png
# attrs-25.3.0.dist-info/
# base_library.zip
# certifi/
# charset_normalizer/
# frozenlist/
# google/
# googleapiclient/
# google_api_core-2.25.0rc1.dist-info/
# google_api_python_client-2.170.0.dist-info/
# grpc/
# httplib2/
# _internal/
# libapparmor.so.1

# %%
# Komórka 8: BARDZO AGRESYWNE oczyszczanie AppDir (z przywróconą sekcją !rm)
import os
import shutil
import glob

print(f"\n--- Rozpoczęcie BARDZO AGRESYWNEGO oczyszczania AppDir: {APPDIR_FULL_PATH} ---")
if not os.path.isdir(APPDIR_FULL_PATH):
    print(f"BŁĄD KRYTYCZNY: Katalog AppDir '{APPDIR_FULL_PATH}' nie istnieje. Przerywam oczyszczanie.")
    raise FileNotFoundError(f"Katalog AppDir nie znaleziony: {APPDIR_FULL_PATH}")

# Definicje ścieżek bazowych (powinny być zdefiniowane w Komórce 4)
# Zakładamy, że PyInstaller umieszcza PyQt5 w _internal/PyQt5/ a standardowe komponenty Qt w _internal/PyQt5/Qt5/
path_to_pyqt_base = os.path.join(APPDIR_FULL_PATH, "_internal", "PyQt5")
path_to_qt_libs_and_plugins_base = os.path.join(path_to_pyqt_base, "Qt5") # Gdzie są lib, plugins, qml
path_to_internal_libs_general = os.path.join(APPDIR_FULL_PATH, "_internal") # Dla ogólnych bibliotek systemowych

# Sprawdzenie, czy kluczowe katalogi bazowe istnieją
for p_check in [path_to_pyqt_base, path_to_qt_libs_and_plugins_base, path_to_internal_libs_general]:
    if p_check and not os.path.isdir(p_check):
        print(f"OSTRZEŻENIE: Kluczowy katalog bazowy '{p_check}' nie istnieje. Odpowiednie czyszczenie może nie być w pełni skuteczne.")

def remove_item(item_path, item_type="plik/katalog"):
    """Pomocnicza funkcja do usuwania plików lub katalogów."""
    if not item_path:
        print(f"OSTRZEŻENIE: Próba usunięcia z pustej ścieżki (item_path jest None). Pomijam.")
        return

    full_item_path = item_path
    if os.path.exists(full_item_path) or os.path.lexists(full_item_path):
        if os.path.isdir(full_item_path) and not os.path.islink(full_item_path):
            print(f"Usuwam {item_type}: {full_item_path} (katalog)")
            shutil.rmtree(full_item_path, ignore_errors=True)
        else:
            print(f"Usuwam {item_type}: {full_item_path} (plik/dowiązanie)")
            try:
                os.remove(full_item_path)
            except OSError as e:
                print(f"Nie udało się usunąć {full_item_path}: {e}")

# --- 1. Strukturalne usuwanie komponentów Qt z _internal/PyQt5/Qt5/ ---
if os.path.isdir(path_to_qt_libs_and_plugins_base):
    print(f"\nPrzetwarzam strukturalne usuwanie dla bazy komponentów Qt: {path_to_qt_libs_and_plugins_base}")

    remove_item(os.path.join(path_to_qt_libs_and_plugins_base, "qml"), "główny katalog QML")
    qt_lib_dir = os.path.join(path_to_qt_libs_and_plugins_base, 'lib')
    if os.path.isdir(qt_lib_dir):
        libs_qml_quick_to_remove = [
            "libQt5Qml.so.5", "libQt5QmlModels.so.5", "libQt5QmlWorkerScript.so.5",
            "libQt5Quick.so.5", "libQt5QuickControls2.so.5", "libQt5QuickParticles.so.5",
            "libQt5QuickShapes.so.5", "libQt5QuickTemplates2.so.5", "libQt5QuickTest.so.5",
            "libQt5QuickWidgets.so.5"
        ]
        print(f"  Usuwanie bibliotek QML/Quick z: {qt_lib_dir}")
        for lib_name in libs_qml_quick_to_remove:
            remove_item(os.path.join(qt_lib_dir, lib_name), "biblioteka QML/Quick")

    modules_data_to_remove = {
        "Multimedia": ["plugins/audio", "plugins/mediaservice", "plugins/playlistformats", "lib/libQt5Multimedia.so.5", "lib/libQt5MultimediaGstTools.so.5", "lib/libQt5MultimediaQuick.so.5", "lib/libQt5MultimediaWidgets.so.5"],
        "Web": ["plugins/webview", "lib/libQt5WebView.so.5", "lib/libQt5WebSockets.so.5"],
        "3D_and_Assets": ["plugins/assetimporters", "plugins/geometryloaders", "plugins/renderers", "plugins/renderplugins", "plugins/sceneparsers", "lib/libQt5Quick3DAssetImport.so.5", "lib/libQt5Quick3DRender.so.5", "lib/libQt5Quick3DRuntimeRender.so.5", "lib/libQt5Quick3D.so.5", "lib/libQt5Quick3DUtils.so.5", "lib/libQt53DCore.so.5", "lib/libQt53DRender.so.5", "lib/libQt53DInput.so.5", "lib/libQt53DLogic.so.5", "lib/libQt53DAnimation.so.5", "lib/libQt53DExtras.so.5"],
        "Location_and_Positioning": ["plugins/geoservices", "plugins/position", "lib/libQt5Location.so.5", "lib/libQt5Positioning.so.5", "lib/libQt5PositioningQuick.so.5"],
        "Sensors": ["plugins/sensors", "plugins/sensorgestures", "lib/libQt5Sensors.so.5"],
        "SerialPort": ["lib/libQt5SerialPort.so.5"],
        "NfcBluetooth": ["lib/libQt5Nfc.so.5", "lib/libQt5Bluetooth.so.5", "plugins/nfc"],
        "Sql_if_not_used": ["plugins/sqldrivers", "lib/libQt5Sql.so.5"],
        "TestSupport": ["lib/libQt5Test.so.5"],
        "TextToSpeech": ["plugins/texttospeech", "lib/libQt5TextToSpeech.so.5"],
        "DesignerHelp": ["plugins/designer", "lib/libQt5Designer.so.5", "lib/libQt5Help.so.5"],
        "Eglfs": ["lib/libQt5EglFSDeviceIntegration.so.5", "plugins/platforms/libqeglfs.so"],
        "RemoteObjects": ["lib/libQt5RemoteObjects.so.5"],
        "Pdf": ["plugins/imageformats/libqpdf.so", "lib/libQt5Pdf.so.5"],
        "WebGLPlatformPlugin": ["plugins/platforms/libqwebgl.so"],
    }
    for module_name, paths in modules_data_to_remove.items():
        print(f"  Usuwanie modułu: {module_name}")
        for p_rel in paths:
            remove_item(os.path.join(path_to_qt_libs_and_plugins_base, p_rel), f"komponent modułu {module_name}")

    imageformats_plugin_path = os.path.join(path_to_qt_libs_and_plugins_base, "plugins", "imageformats")
    if os.path.isdir(imageformats_plugin_path):
        imageformats_to_remove_libs = ["libqgif.so", "libqicns.so", "libqtga.so", "libqtiff.so", "libqwbmp.so", "libqwebp.so"]
        for fmt_lib_name in imageformats_to_remove_libs:
            remove_item(os.path.join(imageformats_plugin_path, fmt_lib_name), "format obrazu")
else:
    print(f"OSTRZEŻENIE: Katalog komponentów Qt '{path_to_qt_libs_and_plugins_base}' nie istnieje.")

# --- 2. Usuwanie odpowiadających plików .abi3.so i .pyi z _internal/PyQt5/ ---
if os.path.isdir(path_to_pyqt_base):
    print(f"\nPrzetwarzam usuwanie dla bazy PyQt (abi3/pyi): {path_to_pyqt_base}")
    pyqt_bindings_to_remove_prefixes = [
        "QtQml", "QtQuick", "QtQuickWidgets", "QtMultimedia", "QtMultimediaWidgets",
        "QtWebSockets", "QtWebEngineCore", "QtWebEngineWidgets", "QtWebView",
        "Qt3DCore", "Qt3DRender", "Qt3DInput", "Qt3DLogic", "Qt3DAnimation", "Qt3DExtras", "QtQuick3D",
        "QtLocation", "QtPositioning", "QtSensors", "QtSerialPort", "QtNfc", "QtBluetooth",
        "QtSql", "QtTest", "QtTextToSpeech", "QtDesigner", "QtHelp", "QtRemoteObjects", "QtGamepad"
    ]
    for module_prefix in pyqt_bindings_to_remove_prefixes:
        remove_item(os.path.join(path_to_pyqt_base, f"{module_prefix}.abi3.so"), f"PyQt binding {module_prefix}")
        remove_item(os.path.join(path_to_pyqt_base, f"{module_prefix}.pyi"), f"PyQt pyi {module_prefix}")
else:
    print(f"OSTRZEŻENIE: Katalog bazowy PyQt '{path_to_pyqt_base}' nie istnieje.")

# --- 3. Usuwanie zbędnych bibliotek systemowych z _internal/ ---
if os.path.isdir(path_to_internal_libs_general):
    print(f"\nPrzetwarzam usuwanie bibliotek systemowych z: {path_to_internal_libs_general}")
    internal_libs_to_remove_names = [
        "libpulse.so.0", "libsndfile.so.1", "libvorbis.so.0", "libvorbisenc.so.2",
        "libFLAC.so.8", "libopus.so.0", "libogg.so.0", "libasound.so.2",
        "libgstapp-1.0.so.0", "libgstaudio-1.0.so.0", "libgstbase-1.0.so.0",
        "libgstpbutils-1.0.so.0", "libgstreamer-1.0.so.0", "libgsttag-1.0.so.0",
        "libgstvideo-1.0.so.0", "liborc-0.4.so.0", "libpulsecommon-15.99.so",
        "libpulse-mainloop-glib.so.0",
        "libkeyutils.so.1", "libkrb5.so.3", "libk5crypto.so.3", "libkrb5support.so.0",
        "libgssapi_krb5.so.2", "libcom_err.so.2",
        "libldap-2.5.so.0", "liblber-2.5.so.0", "libsasl2.so.2",
        "libcups.so.2", "libodbc.so.2", "libpq.so.5",
        "libapparmor.so.1", "libavahi-client.so.3", "libavahi-common.so.3", "libltdl.so.7",
    ]
    for lib_name in internal_libs_to_remove_names:
        remove_item(os.path.join(path_to_internal_libs_general, lib_name), "biblioteka systemowa")

    python_packages_to_remove_names = [
        "aiohttp", "attrs-25.3.0.dist-info", "frozenlist", "markupsafe",
        "MarkupSafe-3.0.2.dist-info", "multidict", "propcache", "yarl",
        "shell_gpt", "distro", "instructor", "openai", "rich", "typer",
        "click", "shellingham", "markdown-it-py", "pygments", "docstring_parser",
        "jinja2", "jiter", "tenacity", "aiohappyeyeballs", "aiosignal", "anyio",
        "httpx", "httpcore", "h11", "annotated_types",
        "typing_inspection", "mdurl"
    ]
    print(f"\nPrzetwarzam usuwanie pakietów Python z: {path_to_internal_libs_general}")
    for pkg_name in python_packages_to_remove_names:
        remove_item(os.path.join(path_to_internal_libs_general, pkg_name), f"pakiet Python '{pkg_name}'")
else:
    print(f"OSTRZEŻENIE: Główny katalog _internal '{path_to_internal_libs_general}' nie istnieje.")

# --- 4. Dodatkowe polecenia !rm z oryginalnego notatnika (z poprawionymi ścieżkami) ---
print("\nUruchamianie dodatkowych poleceń !rm z oryginalnego notatnika (dla pewności)...")
# Ścieżki są teraz relative do path_to_qt_libs_and_plugins_base dla bibliotek Qt
# lub path_to_pyqt_base dla plików .abi3.so, lub path_to_internal_libs_general
# Te polecenia !rm mogą być teraz w większości nadmiarowe, jeśli powyższe pętle działają poprawnie.

# Multimedia i powiązane
if os.path.isdir(path_to_qt_libs_and_plugins_base):
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/mediaservice/libgstcamerabin.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/mediaservice/libgstaudiodecoder.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/mediaservice/libgstmediacapture.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/mediaservice/libgstmediaplayer.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/playlistformats/libqtmultimedia_m3u.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/audio/libqtaudio_alsa.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/audio/libqtmedia_pulse.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5MultimediaWidgets.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5MultimediaGstTools.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Multimedia.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5MultimediaQuick.so.5')}"

if os.path.isdir(path_to_pyqt_base):
    # !rm -f "{os.path.join(path_to_pyqt_base, 'QtMultimedia.abi3.so')}"
    # !rm -f "{os.path.join(path_to_pyqt_base, 'QtMultimediaWidgets.abi3.so')}"
    # !rm -f "{os.path.join(path_to_pyqt_base, 'QtTextToSpeech.abi3.so')}"
    # !rm -f "{os.path.join(path_to_pyqt_base, 'QtPositioning.abi3.so')}"
    # !rm -f "{os.path.join(path_to_pyqt_base, 'QtLocation.abi3.so')}"
    # !rm -f "{os.path.join(path_to_pyqt_base, 'QtBluetooth.abi3.so')}"
    # !rm -f "{os.path.join(path_to_pyqt_base, 'QtSerialPort.abi3.so')}" # Może nie istnieć, -f obsłuży

# Web i QML (większość powinna być już usunięta przez wykluczenia PyInstallera i pętle)
if os.path.isdir(path_to_qt_libs_and_plugins_base):
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/platforms/libqwebgl.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/webview/libqtwebview_webengine.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'qml/QtQml/RemoteObjects/libqtqmlremoteobjects.so')}" # Stara ścieżka, prawdopodobnie już nieistniejąca
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'qml/QtQuick/Scene2D/libqtquickscene2dplugin.so')}" # Stara ścieżka

# 3D i Sceneparsers
if os.path.isdir(path_to_qt_libs_and_plugins_base):
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/sceneparsers/libgltfsceneimport.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/sceneparsers/libassimpsceneimport.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/sceneparsers/libgltfsceneexport.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/renderers/libopenglrenderer.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/geometryloaders/libdefaultgeometryloader.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/geometryloaders/libgltfgeometryloader.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/renderplugins/libscene2d.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/texttospeech/libqtexttospeech_speechd.so')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Location.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Positioning.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Sensors.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Nfc.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Bluetooth.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Sql.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Test.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5PositioningQuick.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5PrintSupport.so.5')}" # Zostawiamy
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5WebView.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5OpenGL.so.5')}" # Zostawiamy
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Quick3DRender.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Quick3D.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Quick3DRuntimeRender.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Quick3DAssetImport.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5Quick3DUtils.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5TextToSpeech.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5WebSockets.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'lib/libQt5SerialPort.so.5')}"
    # !rm -f "{os.path.join(path_to_qt_libs_and_plugins_base, 'plugins/platforms/libqwebgl.so')}" # Ponownie, dla pewności
    # !rm -f /content/LinuxAIAssistant.AppDir/_internal/libQt5Location.so.5
    # !rm -f /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/playlistformats/libqtmultimedia_m3u.so
    # !rm -f /content/LinuxAIAssistant.AppDir/_internal/libQt5MultimediaWidgets.so.5
    # !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice/libgstmediacapture.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice/libgstaudiodecoder.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/qml/QtQml/RemoteObjects/libqtqmlremoteobjects.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtTextToSpeech.abi3.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/qml/QtQuick/Scene2D/libqtquickscene2dplugin.so
# !rm content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice/libgstmediacapture.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice/libgstmediaplayer.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice/libgstaudiodecoder.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtXmlPatterns.abi3.so1
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/webview/libqtwebview_webengine.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtScript.abi3.so1
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtScriptTools.abi3.so1
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneimport.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtDesignerComponents.abi3.so1
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtHelp.abi3.so1
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/sceneparsers/libassimpsceneimport.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtBluetooth.abi3.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtTextToSpeech.abi3.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtLocation.abi3.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtSerialPort.abi3.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/playlistformats/libqtmultimedia_m3u.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneexport.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/audio/libqtaudio_alsa.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/audio/libqtmedia_pulse.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/renderers/libopenglrenderer.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqpdf.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/geometryloaders/libdefaultgeometryloader.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtMultimedia.abi3.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/geometryloaders/libgltfgeometryloader.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/renderplugins/libscene2d.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/texttospeech/libqtexttospeech_speechd.so
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5MultimediaWidgets.so.5
# !rm content/LinuxAIAssistant.AppDir/_internal/libQt5MultimediaGstTools.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Location.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Positioning.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Sensors.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Nfc.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Bluetooth.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Sql.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Test.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5MultimediaGstTools.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Multimedia.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5MultimediaQuick.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5PositioningQuick.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5PrintSupport.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5WebView.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5OpenGL.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DRender.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3D.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DRuntimeRender.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DAssetImport.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DUtils.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DQuick.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DInput.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DLogic.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DAnimation.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DExtras.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DQuickAnimation.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DQuickExtras.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DQuickInput.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5OpenGL.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5TextToSpeech.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5WebSockets.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/libQt5SerialPort.so.5
# !rm /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqwebgl.so


print("Dodatkowe polecenia !rm wykonane.")

print("\nUsuwanie pustych katalogów (ponownie, po !rm)...")
for root_dir_walk, nested_dirs_walk, _ in os.walk(APPDIR_FULL_PATH, topdown=False):
    for name_dir_walk in nested_dirs_walk:
        dir_path_to_check_walk = os.path.join(root_dir_walk, name_dir_walk)
        try:
            if not os.listdir(dir_path_to_check_walk):
                print(f"Usuwam pusty katalog: {dir_path_to_check_walk}")
                os.rmdir(dir_path_to_check_walk)
        except OSError as e:
            print(f"Nie udało się usunąć/sprawdzić pustego katalogu {dir_path_to_check_walk}: {e}")

print(f"\n--- Zakończono zaawansowane oczyszczanie AppDir (w tym komendy !rm) ---")
if os.path.exists(APPDIR_FULL_PATH):
    size_bytes_total_after_cleanup = sum(os.path.getsize(os.path.join(dp_curr, f_curr)) for dp_curr, _, fn_curr in os.walk(APPDIR_FULL_PATH) for f_curr in fn_curr if not os.path.islink(os.path.join(dp_curr, f_curr)))
    print(f"Aktualny rozmiar katalogu '{APPDIR_FULL_PATH}' po oczyszczaniu: {size_bytes_total_after_cleanup / (1024*1024):.2f} MB")

# --- Dodatkowa weryfikacja po usunięciu ---
print("\n--- Weryfikacja kluczowych usunięć (Komórka 8) ---")
paths_to_verify_deletion_final = [
    os.path.join(path_to_qt_libs_and_plugins_base, "qml", "QtQml", "WorkerScript.2", "libworkerscriptplugin.so"),
    os.path.join(path_to_qt_libs_and_plugins_base, "lib", "libQt5QmlWorkerScript.so.5"),
    os.path.join(path_to_qt_libs_and_plugins_base, "plugins", "platforms", "libqwebgl.so"),
    os.path.join(path_to_qt_libs_and_plugins_base, "lib", "libQt5WebSockets.so.5"),
    os.path.join(path_to_pyqt_base, "QtWebSockets.abi3.so"),
    os.path.join(path_to_qt_libs_and_plugins_base, "plugins", "assetimporters", "libuip.so"),
    os.path.join(path_to_qt_libs_and_plugins_base, "plugins", "assetimporters"),
    os.path.join(path_to_qt_libs_and_plugins_base, "lib", "libQt5Quick3DAssetImport.so.5"),
    os.path.join(path_to_qt_libs_and_plugins_base, "plugins", "playlistformats", "libqtmultimedia_m3u.so"),
    os.path.join(path_to_internal_libs_general, "libpulse-mainloop-glib.so.0"),
]
for p_verify_item_final in paths_to_verify_deletion_final:
    if os.path.exists(p_verify_item_final):
        print(f"BŁĄD WERYFIKACJI: Ścieżka '{p_verify_item_final}' NADAL ISTNIEJE!")
        if os.path.isdir(p_verify_item_final) and os.path.exists(os.path.join(p_verify_item_final, '')) :
            try:
                if os.listdir(p_verify_item_final):
                     print(f"  (Zawartość katalogu '{p_verify_item_final}': {os.listdir(p_verify_item_final)[:5]})")
            except Exception as e_list:
                print(f"  (Błąd przy listowaniu zawartości '{p_verify_item_final}': {e_list})")
    else:
        print(f"OK WERYFIKACJI: Ścieżka '{p_verify_item_final}' została usunięta lub nie istniała.")
print("--- Koniec weryfikacji po usunięciu (Komórka 8) ---")
# Out:
# --- Rozpoczęcie BARDZO AGRESYWNEGO oczyszczania AppDir: /content/LinuxAIAssistant.AppDir ---
#
# Przetwarzam strukturalne usuwanie dla bazy komponentów Qt: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5
# Usuwam główny katalog QML: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/qml (katalog)
#   Usuwanie bibliotek QML/Quick z: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib
# Usuwam biblioteka QML/Quick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Qml.so.5 (plik/dowiązanie)
# Usuwam biblioteka QML/Quick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5QmlModels.so.5 (plik/dowiązanie)
# Usuwam biblioteka QML/Quick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5QmlWorkerScript.so.5 (plik/dowiązanie)
# Usuwam biblioteka QML/Quick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Quick.so.5 (plik/dowiązanie)
# Usuwam biblioteka QML/Quick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5QuickControls2.so.5 (plik/dowiązanie)
# Usuwam biblioteka QML/Quick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5QuickParticles.so.5 (plik/dowiązanie)
# Usuwam biblioteka QML/Quick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5QuickShapes.so.5 (plik/dowiązanie)
# Usuwam biblioteka QML/Quick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5QuickTemplates2.so.5 (plik/dowiązanie)
# Usuwam biblioteka QML/Quick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5QuickTest.so.5 (plik/dowiązanie)
# Usuwam biblioteka QML/Quick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5QuickWidgets.so.5 (plik/dowiązanie)
#   Usuwanie modułu: Multimedia
# Usuwam komponent modułu Multimedia: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/audio (katalog)
# Usuwam komponent modułu Multimedia: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice (katalog)
# Usuwam komponent modułu Multimedia: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/playlistformats (katalog)
# Usuwam komponent modułu Multimedia: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Multimedia.so.5 (plik/dowiązanie)
# Usuwam komponent modułu Multimedia: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5MultimediaGstTools.so.5 (plik/dowiązanie)
# Usuwam komponent modułu Multimedia: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5MultimediaQuick.so.5 (plik/dowiązanie)
# Usuwam komponent modułu Multimedia: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5MultimediaWidgets.so.5 (plik/dowiązanie)
#   Usuwanie modułu: Web
# Usuwam komponent modułu Web: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/webview (katalog)
# Usuwam komponent modułu Web: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5WebView.so.5 (plik/dowiązanie)
# Usuwam komponent modułu Web: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5WebSockets.so.5 (plik/dowiązanie)
#   Usuwanie modułu: 3D_and_Assets
# Usuwam komponent modułu 3D_and_Assets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/assetimporters (katalog)
# Usuwam komponent modułu 3D_and_Assets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/geometryloaders (katalog)
# Usuwam komponent modułu 3D_and_Assets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/renderers (katalog)
# Usuwam komponent modułu 3D_and_Assets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/renderplugins (katalog)
# Usuwam komponent modułu 3D_and_Assets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/sceneparsers (katalog)
# Usuwam komponent modułu 3D_and_Assets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Quick3DAssetImport.so.5 (plik/dowiązanie)
# Usuwam komponent modułu 3D_and_Assets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Quick3DRender.so.5 (plik/dowiązanie)
# Usuwam komponent modułu 3D_and_Assets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Quick3DRuntimeRender.so.5 (plik/dowiązanie)
# Usuwam komponent modułu 3D_and_Assets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Quick3D.so.5 (plik/dowiązanie)
# Usuwam komponent modułu 3D_and_Assets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Quick3DUtils.so.5 (plik/dowiązanie)
#   Usuwanie modułu: Location_and_Positioning
# Usuwam komponent modułu Location_and_Positioning: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/geoservices (katalog)
# Usuwam komponent modułu Location_and_Positioning: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/position (katalog)
# Usuwam komponent modułu Location_and_Positioning: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Location.so.5 (plik/dowiązanie)
# Usuwam komponent modułu Location_and_Positioning: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Positioning.so.5 (plik/dowiązanie)
# Usuwam komponent modułu Location_and_Positioning: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5PositioningQuick.so.5 (plik/dowiązanie)
#   Usuwanie modułu: Sensors
# Usuwam komponent modułu Sensors: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/sensors (katalog)
# Usuwam komponent modułu Sensors: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/sensorgestures (katalog)
# Usuwam komponent modułu Sensors: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Sensors.so.5 (plik/dowiązanie)
#   Usuwanie modułu: SerialPort
# Usuwam komponent modułu SerialPort: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5SerialPort.so.5 (plik/dowiązanie)
#   Usuwanie modułu: NfcBluetooth
# Usuwam komponent modułu NfcBluetooth: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Nfc.so.5 (plik/dowiązanie)
# Usuwam komponent modułu NfcBluetooth: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Bluetooth.so.5 (plik/dowiązanie)
#   Usuwanie modułu: Sql_if_not_used
# Usuwam komponent modułu Sql_if_not_used: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/sqldrivers (katalog)
# Usuwam komponent modułu Sql_if_not_used: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Sql.so.5 (plik/dowiązanie)
#   Usuwanie modułu: TestSupport
# Usuwam komponent modułu TestSupport: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Test.so.5 (plik/dowiązanie)
#   Usuwanie modułu: TextToSpeech
# Usuwam komponent modułu TextToSpeech: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/texttospeech (katalog)
# Usuwam komponent modułu TextToSpeech: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5TextToSpeech.so.5 (plik/dowiązanie)
#   Usuwanie modułu: DesignerHelp
# Usuwam komponent modułu DesignerHelp: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Designer.so.5 (plik/dowiązanie)
# Usuwam komponent modułu DesignerHelp: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Help.so.5 (plik/dowiązanie)
#   Usuwanie modułu: Eglfs
# Usuwam komponent modułu Eglfs: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5EglFSDeviceIntegration.so.5 (plik/dowiązanie)
# Usuwam komponent modułu Eglfs: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqeglfs.so (plik/dowiązanie)
#   Usuwanie modułu: RemoteObjects
# Usuwam komponent modułu RemoteObjects: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5RemoteObjects.so.5 (plik/dowiązanie)
#   Usuwanie modułu: Pdf
# Usuwam komponent modułu Pdf: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqpdf.so (plik/dowiązanie)
#   Usuwanie modułu: WebGLPlatformPlugin
# Usuwam komponent modułu WebGLPlatformPlugin: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqwebgl.so (plik/dowiązanie)
# Usuwam format obrazu: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqgif.so (plik/dowiązanie)
# Usuwam format obrazu: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqicns.so (plik/dowiązanie)
# Usuwam format obrazu: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqtga.so (plik/dowiązanie)
# Usuwam format obrazu: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqtiff.so (plik/dowiązanie)
# Usuwam format obrazu: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqwbmp.so (plik/dowiązanie)
# Usuwam format obrazu: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqwebp.so (plik/dowiązanie)
#
# Przetwarzam usuwanie dla bazy PyQt (abi3/pyi): /content/LinuxAIAssistant.AppDir/_internal/PyQt5
# Usuwam PyQt binding QtQml: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtQml.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtQml: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtQml.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtQuick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtQuick.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtQuick: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtQuick.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtQuickWidgets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtQuickWidgets.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtQuickWidgets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtQuickWidgets.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtMultimedia: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtMultimedia.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtMultimedia: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtMultimedia.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtMultimediaWidgets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtMultimediaWidgets.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtMultimediaWidgets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtMultimediaWidgets.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtWebSockets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtWebSockets.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtWebSockets: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtWebSockets.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtQuick3D: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtQuick3D.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtQuick3D: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtQuick3D.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtLocation: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtLocation.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtLocation: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtLocation.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtPositioning: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtPositioning.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtPositioning: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtPositioning.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtSensors: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtSensors.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtSensors: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtSensors.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtSerialPort: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtSerialPort.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtSerialPort: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtSerialPort.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtNfc: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtNfc.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtNfc: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtNfc.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtBluetooth: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtBluetooth.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtBluetooth: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtBluetooth.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtSql: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtSql.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtSql: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtSql.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtTest: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtTest.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtTest: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtTest.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtTextToSpeech: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtTextToSpeech.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtTextToSpeech: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtTextToSpeech.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtDesigner: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtDesigner.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtDesigner: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtDesigner.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtHelp: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtHelp.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtHelp: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtHelp.pyi (plik/dowiązanie)
# Usuwam PyQt binding QtRemoteObjects: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtRemoteObjects.abi3.so (plik/dowiązanie)
# Usuwam PyQt pyi QtRemoteObjects: /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtRemoteObjects.pyi (plik/dowiązanie)
#
# Przetwarzam usuwanie bibliotek systemowych z: /content/LinuxAIAssistant.AppDir/_internal
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libpulse.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libsndfile.so.1 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libvorbis.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libvorbisenc.so.2 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libFLAC.so.8 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libopus.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libogg.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libasound.so.2 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libgstapp-1.0.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libgstaudio-1.0.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libgstbase-1.0.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libgstpbutils-1.0.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libgstreamer-1.0.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libgsttag-1.0.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libgstvideo-1.0.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/liborc-0.4.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libpulsecommon-15.99.so (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libkeyutils.so.1 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libkrb5.so.3 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libk5crypto.so.3 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libkrb5support.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libgssapi_krb5.so.2 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libcom_err.so.2 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libldap-2.5.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/liblber-2.5.so.0 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libsasl2.so.2 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libcups.so.2 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libodbc.so.2 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libpq.so.5 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libapparmor.so.1 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libavahi-client.so.3 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libavahi-common.so.3 (plik/dowiązanie)
# Usuwam biblioteka systemowa: /content/LinuxAIAssistant.AppDir/_internal/libltdl.so.7 (plik/dowiązanie)
#
# Przetwarzam usuwanie pakietów Python z: /content/LinuxAIAssistant.AppDir/_internal
# Usuwam pakiet Python 'aiohttp': /content/LinuxAIAssistant.AppDir/_internal/aiohttp (katalog)
# Usuwam pakiet Python 'attrs-25.3.0.dist-info': /content/LinuxAIAssistant.AppDir/_internal/attrs-25.3.0.dist-info (katalog)
# Usuwam pakiet Python 'frozenlist': /content/LinuxAIAssistant.AppDir/_internal/frozenlist (katalog)
# Usuwam pakiet Python 'markupsafe': /content/LinuxAIAssistant.AppDir/_internal/markupsafe (katalog)
# Usuwam pakiet Python 'MarkupSafe-3.0.2.dist-info': /content/LinuxAIAssistant.AppDir/_internal/MarkupSafe-3.0.2.dist-info (katalog)
# Usuwam pakiet Python 'multidict': /content/LinuxAIAssistant.AppDir/_internal/multidict (katalog)
# Usuwam pakiet Python 'propcache': /content/LinuxAIAssistant.AppDir/_internal/propcache (katalog)
# Usuwam pakiet Python 'yarl': /content/LinuxAIAssistant.AppDir/_internal/yarl (katalog)
#
# Uruchamianie dodatkowych poleceń !rm z oryginalnego notatnika (dla pewności)...
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice/libgstmediacapture.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice/libgstaudiodecoder.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/qml/QtQml/RemoteObjects/libqtqmlremoteobjects.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtTextToSpeech.abi3.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/qml/QtQuick/Scene2D/libqtquickscene2dplugin.so': No such file or directory
# rm: cannot remove 'content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice/libgstmediacapture.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice/libgstmediaplayer.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/mediaservice/libgstaudiodecoder.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtXmlPatterns.abi3.so1': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/webview/libqtwebview_webengine.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtScript.abi3.so1': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtScriptTools.abi3.so1': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneimport.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtDesignerComponents.abi3.so1': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtHelp.abi3.so1': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/sceneparsers/libassimpsceneimport.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtBluetooth.abi3.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtTextToSpeech.abi3.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtLocation.abi3.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtSerialPort.abi3.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/playlistformats/libqtmultimedia_m3u.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/sceneparsers/libgltfsceneexport.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/audio/libqtaudio_alsa.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/audio/libqtmedia_pulse.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/renderers/libopenglrenderer.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqpdf.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/geometryloaders/libdefaultgeometryloader.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtMultimedia.abi3.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/geometryloaders/libgltfgeometryloader.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/renderplugins/libscene2d.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/texttospeech/libqtexttospeech_speechd.so': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5MultimediaWidgets.so.5': No such file or directory
# rm: cannot remove 'content/LinuxAIAssistant.AppDir/_internal/libQt5MultimediaGstTools.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5Location.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DQuick.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DInput.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DLogic.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DAnimation.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DExtras.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DQuickAnimation.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DQuickExtras.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5Quick3DQuickInput.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/libQt5OpenGL.so.5': No such file or directory
# rm: cannot remove '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqwebgl.so': No such file or directory
# Dodatkowe polecenia !rm wykonane.
#
# Usuwanie pustych katalogów (ponownie, po !rm)...
# Usuwam pusty katalog: /content/LinuxAIAssistant.AppDir/usr/bin
# Usuwam pusty katalog: /content/LinuxAIAssistant.AppDir/usr/lib
#
# --- Zakończono zaawansowane oczyszczanie AppDir (w tym komendy !rm) ---
# Aktualny rozmiar katalogu '/content/LinuxAIAssistant.AppDir' po oczyszczaniu: 319.39 MB
#
# --- Weryfikacja kluczowych usunięć (Komórka 8) ---
# OK WERYFIKACJI: Ścieżka '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/qml/QtQml/WorkerScript.2/libworkerscriptplugin.so' została usunięta lub nie istniała.
# OK WERYFIKACJI: Ścieżka '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5QmlWorkerScript.so.5' została usunięta lub nie istniała.
# OK WERYFIKACJI: Ścieżka '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqwebgl.so' została usunięta lub nie istniała.
# OK WERYFIKACJI: Ścieżka '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5WebSockets.so.5' została usunięta lub nie istniała.
# OK WERYFIKACJI: Ścieżka '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtWebSockets.abi3.so' została usunięta lub nie istniała.
# OK WERYFIKACJI: Ścieżka '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/assetimporters/libuip.so' została usunięta lub nie istniała.
# OK WERYFIKACJI: Ścieżka '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/assetimporters' została usunięta lub nie istniała.
# OK WERYFIKACJI: Ścieżka '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Quick3DAssetImport.so.5' została usunięta lub nie istniała.
# OK WERYFIKACJI: Ścieżka '/content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/playlistformats/libqtmultimedia_m3u.so' została usunięta lub nie istniała.
# OK WERYFIKACJI: Ścieżka '/content/LinuxAIAssistant.AppDir/_internal/libpulse-mainloop-glib.so.0' została usunięta lub nie istniała.
# --- Koniec weryfikacji po usunięciu (Komórka 8) ---

# %%
# Komórka 9: Uruchomienie linuxdeployqt i budowanie AppImage
import os
import shutil
import glob
import subprocess

# Upewnij się, że zmienne globalne są dostępne
# APPDIR_FULL_PATH, APP_EXECUTABLE_NAME_IN_APPDIR_ROOT, COLAB_CONTENT_DIR,
# PROJECT_ROOT_IN_COLAB, ICON_DESKTOP_ENTRY_NAME

LINUXDEPLOYQT_EXEC = "/content/linuxdeployqt"

if os.getcwd() != COLAB_CONTENT_DIR:
    print(f"Zmieniam katalog na: {COLAB_CONTENT_DIR} (był: {os.getcwd()})")
    os.chdir(COLAB_CONTENT_DIR)
else:
    print(f"Już jestem w katalogu: {COLAB_CONTENT_DIR}")

app_binary_in_appdir_root = os.path.join(APPDIR_FULL_PATH, APP_EXECUTABLE_NAME_IN_APPDIR_ROOT)

print(f"\nSprawdzanie istnienia pliku binarnego aplikacji w AppDir: {app_binary_in_appdir_root}")
if not os.path.exists(app_binary_in_appdir_root):
    print(f"BŁĄD KRYTYCZNY: Plik binarny '{app_binary_in_appdir_root}' nie istnieje w korzeniu AppDir!")
else:
    print(f"Plik binarny aplikacji znaleziony: {app_binary_in_appdir_root}")
    print(f"\nSprawdzanie istnienia narzędzia linuxdeployqt: {LINUXDEPLOYQT_EXEC}")
    if not os.path.exists(LINUXDEPLOYQT_EXEC):
        print(f"BŁĄD KRYTYCZNY: Narzędzie linuxdeployqt ('{LINUXDEPLOYQT_EXEC}') nie zostało znalezione!")
    else:
        print(f"Narzędzie linuxdeployqt znalezione. Uruchamianie na: {app_binary_in_appdir_root}")
        command_ldqt = [
            LINUXDEPLOYQT_EXEC,
            app_binary_in_appdir_root,
            "-appimage",
            "-bundle-non-qt-libs",
            "-no-translations",
            "-no-copy-copyright-files",
            "-always-overwrite",
            "-verbose=1"
        ]
        print(f"Polecenie linuxdeployqt: {' '.join(command_ldqt)}")
        env_ldqt = os.environ.copy()
        process_ldqt = subprocess.run(command_ldqt, env=env_ldqt, capture_output=True, text=True, cwd=COLAB_CONTENT_DIR)

        print("--- linuxdeployqt STDOUT ---")
        print(process_ldqt.stdout)
        if process_ldqt.stderr:
            print("--- linuxdeployqt STDERR ---")
            print(process_ldqt.stderr)

        if process_ldqt.returncode == 0:
            print("\nZakończono działanie linuxdeployqt pomyślnie.")
        else:
            print(f"\nBŁĄD: linuxdeployqt zakończył działanie z kodem {process_ldqt.returncode}.")

        appimage_pattern1 = f"{APP_EXECUTABLE_NAME_IN_APPDIR_ROOT}*.AppImage"
        appimage_pattern2 = f"{ICON_DESKTOP_ENTRY_NAME}*.AppImage"
        appimage_files_found = glob.glob(os.path.join(COLAB_CONTENT_DIR, appimage_pattern1))
        if not appimage_files_found:
            appimage_files_found = glob.glob(os.path.join(COLAB_CONTENT_DIR, appimage_pattern2))

        if appimage_files_found:
            final_appimage_path = appimage_files_found[0]
            print(f"\nZnaleziono utworzony AppImage: {final_appimage_path}")
            print("\nInformacje o pliku AppImage:")
            # !ls -lh "{final_appimage_path}"

            destination_filename = f"Linux-AI-Assistant-{os.path.basename(final_appimage_path).replace(APP_EXECUTABLE_NAME_IN_APPDIR_ROOT, '').replace(ICON_DESKTOP_ENTRY_NAME, '').lstrip('-')}"
            if not destination_filename.endswith(".AppImage"): # Na wszelki wypadek
                 destination_filename = f"Linux-AI-Assistant-x86_64.AppImage" # Domyślna nazwa

            destination_path = os.path.join(PROJECT_ROOT_IN_COLAB, destination_filename)
            if os.path.exists(destination_path):
                os.remove(destination_path)
            print(f"Przenoszenie '{final_appimage_path}' do '{destination_path}'")
            shutil.move(final_appimage_path, destination_path)
            if os.path.exists(destination_path):
                print(f"AppImage pomyślnie przeniesione do: {destination_path}")
            else:
                print(f"BŁĄD: Nie udało się przenieść AppImage.")
# Out:
# Zmieniam katalog na: /content (był: /content/LinuxAIAssistant.AppDir)
#
# Sprawdzanie istnienia pliku binarnego aplikacji w AppDir: /content/LinuxAIAssistant.AppDir/LinuxAIAssistant
# Plik binarny aplikacji znaleziony: /content/LinuxAIAssistant.AppDir/LinuxAIAssistant
#
# Sprawdzanie istnienia narzędzia linuxdeployqt: /content/linuxdeployqt
# Narzędzie linuxdeployqt znalezione. Uruchamianie na: /content/LinuxAIAssistant.AppDir/LinuxAIAssistant
# Polecenie linuxdeployqt: /content/linuxdeployqt /content/LinuxAIAssistant.AppDir/LinuxAIAssistant -appimage -bundle-non-qt-libs -no-translations -no-copy-copyright-files -always-overwrite -verbose=1
# --- linuxdeployqt STDOUT ---
# /content/LinuxAIAssistant.AppDir/linux-ai-assistant.desktop: hint: value "Utility;Development;System;" for key "Categories" in group "Desktop Entry" contains more than one main category; application might appear more than once in the application menu
# /content/LinuxAIAssistant.AppDir/linux-ai-assistant.desktop: hint: value "Utility;Development;System;" for key "Categories" in group "Desktop Entry" contains more than one main category; application might appear more than once in the application menu
# Parallel mksquashfs: Using 2 processors
# Creating 4.0 filesystem on Linux_AI_Assistant-x86_64.AppImage, block size 131072.
#
# [=\                                                            ]  100/4689   2%
# [===============================/                              ] 2400/4689  51%
# [==========================================================|   ] 4500/4689  95%
# [=============================================================\] 4689/4689 100%
#
# Exportable Squashfs 4.0 filesystem, gzip compressed, data block size 131072
# 	compressed data, compressed metadata, compressed fragments,
# 	compressed xattrs, compressed ids
# 	duplicates are removed
# Filesystem size 112217.48 Kbytes (109.59 Mbytes)
# 	28.51% of uncompressed filesystem size (393554.17 Kbytes)
# Inode table size 29502 bytes (28.81 Kbytes)
# 	36.20% of uncompressed inode table size (81505 bytes)
# Directory table size 24191 bytes (23.62 Kbytes)
# 	40.67% of uncompressed directory table size (59484 bytes)
# Number of duplicate files found 66
# Number of inodes 2170
# Number of files 2058
# Number of fragments 360
# Number of symbolic links  1
# Number of device nodes 0
# Number of fifo nodes 0
# Number of socket nodes 0
# Number of directories 111
# Number of ids (unique uids + gids) 1
# Number of uids 1
# 	root (0)
# Number of gids 1
# 	root (0)
# Desktop file: /content/LinuxAIAssistant.AppDir/linux-ai-assistant.desktop
# /content/LinuxAIAssistant.AppDir should be packaged as Linux_AI_Assistant-x86_64.AppImage
# Size of the embedded runtime: 189632 bytes
#
# --- linuxdeployqt STDERR ---
# linuxdeployqt  (commit 37df8a3), build 91 built on 2025-05-04 15:05:54 UTC
# Not using FHS-like mode
# app-binary: "/content/LinuxAIAssistant.AppDir/LinuxAIAssistant"
# appDirPath: "/content/LinuxAIAssistant.AppDir"
# relativeBinPath: "LinuxAIAssistant"
# Keeping existing AppRun
# appimagetool, continuous build (commit 8bbf694), build <local dev build> built on 2020-12-31 11:48:33 UTC
# fatal: not a git repository (or any of the parent directories): .git
# Failed to run 'git rev-parse --short HEAD: Child process exited with code 128 (code 128)
# Name: Linux AI Assistant
# Icon: linux-ai-assistant
# Exec: LinuxAIAssistant
# Comment: AI Assistant for Linux Commands
# Type: Application
# Categories: Utility;Development;System;
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Gui.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libpng16.so.16 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Help.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libffi.so.8 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5WaylandClient.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5XcbQpa.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libXext.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5WebChannel.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libstdc++.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libcrypto.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5QuickWidgets.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Network.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libgcrypt.so.20 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libp11-kit.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqminimal.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqwayland-xcomposite-egl.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqxcb.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqvnc.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqwayland-xcomposite-glx.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqlinuxfb.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqminimalegl.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqwayland-egl.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqoffscreen.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforms/libqwayland-generic.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/printsupport/libcupsprintersupport.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforminputcontexts/libibusplatforminputcontextplugin.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platforminputcontexts/libcomposeplatforminputcontextplugin.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-decoration-client/libbradient.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-shell-integration/libxdg-shell-v5.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-shell-integration/libfullscreen-shell-v1.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-shell-integration/libxdg-shell-v6.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-shell-integration/libivi-shell.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-shell-integration/libxdg-shell.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-shell-integration/libwl-shell.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/iconengines/libqsvgicon.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/xcbglintegrations/libqxcb-egl-integration.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/xcbglintegrations/libqxcb-glx-integration.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/bearer/libqgenericbearer.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/bearer/libqnmbearer.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/bearer/libqconnmanbearer.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-graphics-integration-client/libxcomposite-egl.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-graphics-integration-client/libqt-plugin-wayland-egl.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-graphics-integration-client/libdrm-egl-server.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-graphics-integration-client/libxcomposite-glx.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-graphics-integration-client/libdmabuf-server.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/wayland-graphics-integration-client/libshm-emulation-server.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/generic/libqevdevtouchplugin.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/generic/libqevdevkeyboardplugin.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/generic/libqevdevtabletplugin.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/generic/libqtuiotouchplugin.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/generic/libqevdevmouseplugin.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqsvg.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqico.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/imageformats/libqjpeg.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/plugins/platformthemes/libqxdgdesktopportal.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Gui.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5WaylandClient.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5XcbQpa.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5WebChannel.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Network.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5X11Extras.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5PrintSupport.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Xml.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libicui18n.so.56 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Widgets.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5XmlPatterns.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libicudata.so.56 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Concurrent.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5OpenGL.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5DBus.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libicuuc.so.56 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Core.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt5/lib/libQt5Svg.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/pylupdate.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/sip.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtWidgets.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtWebChannel.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/Qt.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/_QOpenGLFunctions_2_1.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtSvg.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/_QOpenGLFunctions_2_0.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtOpenGL.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtXml.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtXmlPatterns.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtX11Extras.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/pyrcc.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtGui.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtDBus.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtPrintSupport.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtNetwork.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/_QOpenGLFunctions_4_1_Core.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/PyQt5/QtCore.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5EglFSDeviceIntegration.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-util.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/google/_upb/_message.abi3.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libglib-2.0.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libbsd.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libunistring.so.2 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxkbcommon-x11.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5QuickTemplates2.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libX11-xcb.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5X11Extras.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libfontconfig.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5QuickTest.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-glx.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libXdmcp.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/pydantic_core/_pydantic_core.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5QuickShapes.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Qml.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libgmp.so.10 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libgthread-2.0.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libtasn1.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-render-util.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Xml.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/liblzma.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-image.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libcap.so.2 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libicui18n.so.56 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/liblz4.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libtinfo.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libgstallocators-1.0.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libbrotlidec.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libidn2.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-xkb.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Widgets.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libgpg-error.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libXcomposite.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_decimal.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_codecs_jp.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_codecs_iso2022.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_codecs_hk.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_typing.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_contextvars.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_multiprocessing.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_codecs_cn.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_asyncio.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_bz2.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_codecs_kr.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_multibytecodec.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_codecs_tw.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/mmap.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_hashlib.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_json.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/resource.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/termios.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_queue.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_posixshmem.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_ssl.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_lzma.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_uuid.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/readline.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/lib-dynload/_zoneinfo.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libgcc_s.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5XmlPatterns.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-shape.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5QmlModels.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/charset_normalizer/md.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/charset_normalizer/md__mypyc.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libzstd.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-randr.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libunwind.so.8 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5QuickControls2.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libexpat.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libbz2.so.1.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libpython3.11.so.1.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libicudata.so.56 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libmd.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/grpc/_cython/cygrpc.cpython-311-x86_64-linux-gnu.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libgmodule-2.0.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libuuid.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-xfixes.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libreadline.so.8 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libdbus-1.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Concurrent.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-sync.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-keysyms.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxkbcommon.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libsystemd.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libfreetype.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5DBus.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libnettle.so.8 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libX11.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libasyncns.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-icccm.so.4 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libz.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libdw.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libelf.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libXau.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Quick.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-render.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libicuuc.so.56 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5RemoteObjects.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libbrotlicommon.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libpcre.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libhogweed.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5QmlWorkerScript.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-xinerama.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libgobject-2.0.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libxcb-shm.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libssl.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Core.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Svg.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libgnutls.so.30 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5QuickParticles.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/_internal/libQt5Designer.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/platforms/libqxcb.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/printsupport/libcupsprintersupport.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/platforminputcontexts/libibusplatforminputcontextplugin.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/platforminputcontexts/libcomposeplatforminputcontextplugin.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/iconengines/libqsvgicon.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/xcbglintegrations/libqxcb-egl-integration.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/xcbglintegrations/libqxcb-glx-integration.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/bearer/libqgenericbearer.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/bearer/libqnmbearer.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/bearer/libqconnmanbearer.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/imageformats/libqsvg.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/imageformats/libqico.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/plugins/imageformats/libqjpeg.so used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libpng16.so.16 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libffi.so.8 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libXext.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libcups.so.2 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libgssapi_krb5.so.2 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libkrb5support.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libcrypto.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libgcrypt.so.20 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libkrb5.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libp11-kit.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libgstreamer-1.0.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libavahi-client.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-util.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libglib-2.0.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libicudata.so.70 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libwayland-cursor.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libbsd.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libunistring.so.2 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxkbcommon-x11.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libkeyutils.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libQt5Test.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-glx.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libicuuc.so.70 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libicui18n.so.70 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libXdmcp.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libk5crypto.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libQt5Qml.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libgthread-2.0.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libtasn1.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-render-util.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libavahi-common.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/liblzma.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-image.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libdouble-conversion.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libcap.so.2 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/liblz4.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libtinfo.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libbrotlidec.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libidn2.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-xkb.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libXcomposite.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-shape.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libwayland-egl.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libQt5Sql.so.5 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libzstd.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-randr.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libunwind.so.8 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libbz2.so.1.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libmd.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libgmodule-2.0.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-xfixes.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libreadline.so.8 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libdbus-1.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-sync.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-keysyms.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxkbcommon.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libsystemd.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libnettle.so.8 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libpcre2-16.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-icccm.so.4 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libdw.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libelf.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libXau.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-render.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libbrotlicommon.so.1 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libpcre.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libhogweed.so.6 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-xinerama.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libgobject-2.0.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libxcb-shm.so.0 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libssl.so.3 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/lib/libgnutls.so.30 used for determining architecture x86_64
# /content/LinuxAIAssistant.AppDir/LinuxAIAssistant used for determining architecture x86_64
# Using architecture x86_64
# App name for filename: Linux_AI_Assistant
# Generating squashfs...
# Embedding ELF...
# Marking the AppImage as executable...
# Embedding MD5 digest
# Success
#
# Please consider submitting your AppImage to AppImageHub, the crowd-sourced
# central directory of available AppImages, by opening a pull request
# at https://github.com/AppImage/appimage.github.io
#
#
# Zakończono działanie linuxdeployqt pomyślnie.
